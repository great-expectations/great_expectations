# %%
import ast
import glob
import re


def get_n_longest_funcs(dir, n):
    function_definitions = []
    for path in glob.glob(f"{dir}/**/*.py", recursive=True):
        with open(path) as f:
            root = ast.parse(f.read(), path)

        for node in ast.walk(root):
            if isinstance(node, ast.FunctionDef):
                length = node.end_lineno - node.lineno
                definition = (node.name, length, path)
                function_definitions.append(definition)

    function_definitions.sort(key=lambda x: x[1], reverse=True)
    return function_definitions[:n]


print("========== Great Expectations ==========")
for func in get_n_longest_funcs("great_expectations", 20):
    print(func)

print("\n========== Tests ==========")
for func in get_n_longest_funcs("tests", 20):
    print(func)
# Out:
# ========== Great Expectations ==========
# ('expect_column_kl_divergence_to_be_less_than', 450, 'great_expectations/dataset/dataset.py')
# ('get_dataset', 424, 'great_expectations/self_check/util.py')
# ('test_yaml_config', 401, 'great_expectations/data_context/data_context.py')
# ('_register_metric_functions', 396, 'great_expectations/expectations/metrics/map_metric_provider.py')
# ('_validate', 358, 'great_expectations/expectations/core/expect_column_kl_divergence_to_be_less_than.py')
# ('validate', 328, 'great_expectations/data_asset/data_asset.py')
# ('generate_expectation_tests', 309, 'great_expectations/self_check/util.py')
# ('validate', 279, 'great_expectations/validator/validator.py')
# ('column_condition_partial', 245, 'great_expectations/expectations/metrics/map_metric_provider.py')
# ('validation_operator_run', 244, 'great_expectations/cli/v012/validation_operator.py')
# ('profile_datasource', 231, 'great_expectations/data_context/data_context.py')
# ('column_pair_condition_partial', 226, 'great_expectations/expectations/metrics/map_metric_provider.py')
# ('render', 217, 'great_expectations/render/renderer/content_block/content_block.py')
# ('column_function_partial', 214, 'great_expectations/expectations/metrics/map_metric_provider.py')
# ('multicolumn_condition_partial', 211, 'great_expectations/expectations/metrics/map_metric_provider.py')
# ('_profile', 206, 'great_expectations/profile/basic_dataset_profiler.py')
# ('column_pair_function_partial', 204, 'great_expectations/expectations/metrics/map_metric_provider.py')
# ('multicolumn_function_partial', 199, 'great_expectations/expectations/metrics/map_metric_provider.py')
# ('render', 197, 'great_expectations/render/renderer/page_renderer.py')
# ('expectation', 195, 'great_expectations/data_asset/data_asset.py')
#
# ========== Tests ==========
# ('numeric_high_card_dict', 1005, 'tests/conftest.py')
# ('bobby_columnar_table_multi_batch', 676, 'tests/rule_based_profiler/bobby_user_workflow_fixture.py')
# ('test_custom_class', 611, 'tests/test_great_expectations.py')
# ('non_numeric_high_card_dataset', 442, 'tests/conftest.py')
# ('test_profile_integer_ranges_schema', 417, 'tests/profile/test_jsonschema_profiler.py')
# ('test_profile_number_ranges_schema', 381, 'tests/profile/test_jsonschema_profiler.py')
# ('test_basic_checkpoint_config_validation', 338, 'tests/checkpoint/test_checkpoint.py')
# ('test_complex_suite_with_batch_request', 338, 'tests/render/renderer/v3/test_suite_edit_notebook_renderer.py')
# ('test_introspect_db', 321, 'tests/datasource/test_new_datasource_with_sql_data_connector.py')
# ('test_newstyle_checkpoint_instantiates_and_produces_a_validation_result_when_run_batch_request_object_multi_validation_pandasdf', 314, 'tests/checkpoint/test_checkpoint.py')
# ('test_SimpleSqlalchemyDatasource', 310, 'tests/datasource/test_new_datasource_with_sql_data_connector.py')
# ('test_format_map_output', 293, 'tests/data_asset/test_data_asset_internals.py')
# ('test_newstyle_checkpoint_config_substitution_nested', 282, 'tests/checkpoint/test_checkpoint.py')
# ('titanic_pandas_data_context_with_v013_datasource_stats_enabled_with_checkpoints_v1_with_templates', 280, 'tests/conftest.py')
# ('test_complex_suite', 279, 'tests/render/renderer/test_suite_edit_notebook_renderer.py')
# ('pytest_generate_tests', 277, 'tests/test_definitions/test_expectations_cfe.py')
# ('test_ValidationResultsTableContentBlockRenderer_get_unexpected_table', 266, 'tests/render/test_render_ValidationResultsTableContentBlockRenderer.py')
# ('test_validate_distribution_parameters', 265, 'tests/dataset/test_dataset_util_legacy.py')
# ('test_configuration_driven_site_builder', 260, 'tests/render/test_data_documentation_site_builder.py')
# ('test_newstyle_checkpoint_config_substitution_simple', 254, 'tests/checkpoint/test_checkpoint.py')

# %%
def parse_coverage_report():
    with open("test_coverage.txt") as f:
        contents = f.readlines()
        
    vals = []
    for line in contents:
        parts = [l.strip() for l in line.split()]
        if not parts[0].startswith("great_expectations"):
            continue
        name, stmts, miss, cover = parts
        val = (name, int(cover.strip("%")))
        vals.append(val)
        
    vals.sort(key=lambda x: x[1])
    for val in vals:
        print(val)
        
parse_coverage_report()
# Out:
# ('great_expectations/cli/build_docs.py', 0)
# ('great_expectations/cli/checkpoint.py', 0)
# ('great_expectations/cli/checkpoint_script_template.py', 0)
# ('great_expectations/cli/datasource.py', 0)
# ('great_expectations/cli/docs.py', 0)
# ('great_expectations/cli/init.py', 0)
# ('great_expectations/cli/project.py', 0)
# ('great_expectations/cli/python_subprocess.py', 0)
# ('great_expectations/cli/store.py', 0)
# ('great_expectations/cli/util.py', 0)
# ('great_expectations/cli/v012/checkpoint_script_template.py', 0)
# ('great_expectations/cli/validation_operator.py', 0)
# ('great_expectations/expectations/core/expect_column_bootstrapped_ks_test_p_value_to_be_greater_than.py', 0)
# ('great_expectations/expectations/core/expect_column_chisquare_test_p_value_to_be_greater_than.py', 0)
# ('great_expectations/expectations/core/expect_column_parameterized_distribution_ks_test_p_value_to_be_greater_than.py', 0)
# ('great_expectations/expectations/metrics/column_aggregate_metric.py', 0)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_bootstrapped_ks_test_p_value.py', 0)
# ('great_expectations/expectations/metrics/map_metric.py', 0)
# ('great_expectations/expectations/metrics/table_metric.py', 0)
# ('great_expectations/expectations/validation_handlers.py', 0)
# ('great_expectations/profile/metrics_utils.py', 0)
# ('great_expectations/render/page_renderer_util.py', 0)
# ('great_expectations/jupyter_ux/expectation_explorer.py', 8)
# ('great_expectations/cli/upgrade_helpers/upgrade_helper_v11.py', 12)
# ('great_expectations/cli/v012/upgrade_helpers/upgrade_helper_v11.py', 12)
# ('great_expectations/cli/v012/python_subprocess.py', 14)
# ('great_expectations/cli/toolkit.py', 16)
# ('great_expectations/cli/v012/datasource.py', 16)
# ('great_expectations/cli/upgrade_helpers/upgrade_helper_v13.py', 18)
# ('great_expectations/execution_engine/util.py', 18)
# ('great_expectations/cli/batch_request.py', 20)
# ('great_expectations/cli/v012/validation_operator.py', 21)
# ('great_expectations/cli/v012/init.py', 22)
# ('great_expectations/cli/v012/upgrade_helpers/upgrade_helper_v13.py', 22)
# ('great_expectations/cli/pretty_printing.py', 25)
# ('great_expectations/cli/v012/toolkit.py', 25)
# ('great_expectations/cli/v012/util.py', 25)
# ('great_expectations/cli/suite.py', 29)
# ('great_expectations/expectations/metrics/util.py', 29)
# ('great_expectations/cli/v012/store.py', 32)
# ('great_expectations/cli/v012/checkpoint.py', 35)
# ('great_expectations/cli/v012/docs.py', 36)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_json_parseable.py', 40)
# ('great_expectations/cli/v012/suite.py', 41)
# ('great_expectations/cli/cli_logging.py', 42)
# ('great_expectations/cli/v012/cli_logging.py', 42)
# ('great_expectations/cli/v012/project.py', 42)
# ('great_expectations/cli/mark.py', 44)
# ('great_expectations/_version.py', 45)
# ('great_expectations/cli/cli.py', 46)
# ('great_expectations/expectations/metrics/import_manager.py', 47)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_quantile_values.py', 49)
# ('great_expectations/marshmallow__shade/validate.py', 50)
# ('great_expectations/jupyter_ux/__init__.py', 51)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_parameterized_distribution_ks_test_p_value.py', 52)
# ('great_expectations/marshmallow__shade/class_registry.py', 52)
# ('great_expectations/marshmallow__shade/orderedset.py', 52)
# ('great_expectations/marshmallow__shade/utils.py', 52)
# ('great_expectations/expectations/core/expect_column_pair_values_a_to_be_greater_than_b.py', 53)
# ('great_expectations/expectations/core/expect_column_pair_cramers_phi_value_to_be_less_than.py', 54)
# ('great_expectations/expectations/core/expect_column_distinct_values_to_equal_set.py', 55)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_of_type.py', 56)
# ('great_expectations/data_context/store/json_site_store.py', 57)
# ('great_expectations/expectations/core/expect_column_stdev_to_be_between.py', 57)
# ('great_expectations/expectations/core/expect_column_values_to_not_be_in_set.py', 57)
# ('great_expectations/checkpoint/types/checkpoint_result.py', 58)
# ('great_expectations/expectations/core/expect_column_pair_values_to_be_equal.py', 58)
# ('great_expectations/expectations/core/expect_column_sum_to_be_between.py', 59)
# ('great_expectations/expectations/core/expect_column_value_lengths_to_equal.py', 59)
# ('great_expectations/expectations/core/expect_column_values_to_be_decreasing.py', 59)
# ('great_expectations/expectations/core/expect_column_values_to_match_regex_list.py', 59)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_match_json_schema.py', 59)
# ('great_expectations/marshmallow__shade/error_store.py', 59)
# ('great_expectations/expectations/core/expect_column_values_to_be_increasing.py', 60)
# ('great_expectations/expectations/core/expect_column_values_to_match_json_schema.py', 60)
# ('great_expectations/expectations/core/expect_multicolumn_values_to_be_unique.py', 60)
# ('great_expectations/expectations/core/expect_column_values_to_not_match_regex_list.py', 61)
# ('great_expectations/core/metric.py', 62)
# ('great_expectations/expectations/core/expect_column_values_to_match_strftime_format.py', 62)
# ('great_expectations/expectations/core/expect_column_values_to_be_json_parseable.py', 63)
# ('great_expectations/expectations/core/expect_select_column_values_to_be_unique_within_record.py', 63)
# ('great_expectations/marshmallow__shade/fields.py', 63)
# ('great_expectations/rule_based_profiler/domain_builder/simple_semantic_type_domain_builder.py', 64)
# ('great_expectations/dataset/sqlalchemy_dataset.py', 65)
# ('great_expectations/execution_engine/sqlalchemy_batch_data.py', 65)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_values_between_count.py', 65)
# ('great_expectations/expectations/metrics/table_metrics/table_head.py', 66)
# ('great_expectations/dataset/__init__.py', 67)
# ('great_expectations/datasource/batch_kwargs_generator/databricks_batch_kwargs_generator.py', 67)
# ('great_expectations/execution_engine/sqlalchemy_execution_engine.py', 67)
# ('great_expectations/expectations/core/expect_column_most_common_value_to_be_in_set.py', 67)
# ('great_expectations/expectations/core/expect_column_value_lengths_to_be_between.py', 67)
# ('great_expectations/expectations/core/expect_column_values_to_be_dateutil_parseable.py', 68)
# ('great_expectations/expectations/core/expect_column_values_to_be_null.py', 68)
# ('great_expectations/data_context/store/ge_cloud_store_backend.py', 69)
# ('great_expectations/data_context/store/util.py', 69)
# ('great_expectations/expectations/core/expect_column_distinct_values_to_contain_set.py', 69)
# ('great_expectations/expectations/core/expect_table_column_count_to_be_between.py', 69)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_match_strftime_format.py', 69)
# ('great_expectations/core/data_context_key.py', 70)
# ('great_expectations/datasource/batch_kwargs_generator/s3_subdir_reader_batch_kwargs_generator.py', 70)
# ('great_expectations/expectations/core/expect_column_values_to_be_of_type.py', 70)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_between.py', 70)
# ('great_expectations/cli/upgrade_helpers/base_upgrade_helper.py', 71)
# ('great_expectations/cli/v012/upgrade_helpers/base_upgrade_helper.py', 71)
# ('great_expectations/expectations/core/expect_column_values_to_match_like_pattern.py', 71)
# ('great_expectations/self_check/util.py', 71)
# ('great_expectations/data_context/store/database_store_backend.py', 72)
# ('great_expectations/data_context/store/html_site_store.py', 72)
# ('great_expectations/checkpoint/util.py', 73)
# ('great_expectations/datasource/batch_kwargs_generator/batch_kwargs_generator.py', 73)
# ('great_expectations/datasource/batch_kwargs_generator/manual_batch_kwargs_generator.py', 73)
# ('great_expectations/datasource/types/batch_kwargs.py', 73)
# ('great_expectations/expectations/core/expect_column_values_to_not_match_like_pattern.py', 73)
# ('great_expectations/expectations/row_conditions.py', 73)
# ('great_expectations/data_context/store/tuple_store_backend.py', 74)
# ('great_expectations/expectations/core/expect_column_values_to_match_like_pattern_list.py', 74)
# ('great_expectations/expectations/core/expect_column_values_to_not_match_like_pattern_list.py', 74)
# ('great_expectations/expectations/registry.py', 74)
# ('great_expectations/expectations/core/expect_column_unique_value_count_to_be_between.py', 75)
# ('great_expectations/expectations/core/expect_column_values_to_not_match_regex.py', 75)
# ('great_expectations/marshmallow__shade/schema.py', 75)
# ('great_expectations/datasource/sqlalchemy_datasource.py', 76)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_value_counts.py', 76)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_not_match_regex_list.py', 76)
# ('great_expectations/expectations/metrics/meta_metric_provider.py', 76)
# ('great_expectations/profile/basic_dataset_profiler.py', 76)
# ('great_expectations/expectations/core/expect_column_median_to_be_between.py', 77)
# ('great_expectations/expectations/core/expect_column_min_to_be_between.py', 77)
# ('great_expectations/expectations/core/expect_column_values_to_be_between.py', 77)
# ('great_expectations/expectations/metrics/map_metric_provider.py', 77)
# ('great_expectations/cli/v012/mark.py', 78)
# ('great_expectations/datasource/batch_kwargs_generator/s3_batch_kwargs_generator.py', 78)
# ('great_expectations/datasource/data_connector/util.py', 78)
# ('great_expectations/expectations/core/expect_column_mean_to_be_between.py', 78)
# ('great_expectations/expectations/core/expect_column_values_to_be_in_set.py', 78)
# ('great_expectations/expectations/core/expect_table_columns_to_match_set.py', 78)
# ('great_expectations/expectations/core/expect_table_row_count_to_equal_other_table.py', 78)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_not_in_set.py', 78)
# ('great_expectations/render/renderer/content_block/content_block.py', 78)
# ('great_expectations/checkpoint/actions.py', 79)
# ('great_expectations/core/usage_statistics/usage_statistics.py', 79)
# ('great_expectations/datasource/batch_kwargs_generator/table_batch_kwargs_generator.py', 79)
# ('great_expectations/expectations/core/expect_column_max_to_be_between.py', 79)
# ('great_expectations/expectations/core/expect_column_value_z_scores_to_be_less_than.py', 79)
# ('great_expectations/render/renderer/content_block/expectation_string.py', 79)
# ('great_expectations/util.py', 79)
# ('great_expectations/datasource/data_connector/configured_asset_gcs_data_connector.py', 80)
# ('great_expectations/data_context/store/query_store.py', 81)
# ('great_expectations/datasource/batch_kwargs_generator/query_batch_kwargs_generator.py', 81)
# ('great_expectations/datasource/data_connector/inferred_asset_s3_data_connector.py', 81)
# ('great_expectations/expectations/core/expect_column_distinct_values_to_be_in_set.py', 81)
# ('great_expectations/expectations/core/expect_column_kl_divergence_to_be_less_than.py', 81)
# ('great_expectations/expectations/core/expect_column_values_to_not_be_null.py', 81)
# ('great_expectations/render/renderer/content_block/profiling_column_properties_table_content_block.py', 81)
# ('great_expectations/validator/validator.py', 81)
# ('great_expectations/core/expectation_validation_result.py', 82)
# ('great_expectations/data_context/types/refs.py', 82)
# ('great_expectations/dataset/sparkdf_dataset.py', 82)
# ('great_expectations/expectations/core/expect_column_values_to_be_unique.py', 82)
# ('great_expectations/expectations/metrics/table_metrics/table_column_types.py', 82)
# ('great_expectations/render/renderer/email_renderer.py', 82)
# ('great_expectations/cli/v012/cli.py', 83)
# ('great_expectations/core/util.py', 83)
# ('great_expectations/data_context/store/store.py', 83)
# ('great_expectations/data_context/types/resource_identifiers.py', 83)
# ('great_expectations/datasource/data_connector/inferred_asset_gcs_data_connector.py', 83)
# ('great_expectations/datasource/pandas_datasource.py', 83)
# ('great_expectations/expectations/core/expect_column_pair_values_to_be_in_set.py', 83)
# ('great_expectations/expectations/core/expect_column_proportion_of_unique_values_to_be_between.py', 83)
# ('great_expectations/expectations/core/expect_column_to_exist.py', 83)
# ('great_expectations/expectations/core/expect_column_values_to_match_regex.py', 83)
# ('great_expectations/expectations/core/expect_table_row_count_to_be_between.py', 83)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_match_like_pattern_list.py', 83)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_null.py', 83)
# ('great_expectations/marshmallow__shade/exceptions.py', 83)
# ('great_expectations/datasource/data_connector/configured_asset_azure_data_connector.py', 84)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_partition.py', 84)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_standard_deviation.py', 84)
# ('great_expectations/render/renderer/content_block/validation_results_table_content_block.py', 84)
# ('great_expectations/rule_based_profiler/parameter_builder/parameter_builder.py', 84)
# ('great_expectations/core/usage_statistics/util.py', 85)
# ('great_expectations/data_context/store/validations_store.py', 85)
# ('great_expectations/datasource/batch_kwargs_generator/glob_reader_batch_kwargs_generator.py', 85)
# ('great_expectations/datasource/data_connector/configured_asset_s3_data_connector.py', 85)
# ('great_expectations/datasource/data_connector/sorter/lexicographic_sorter.py', 85)
# ('great_expectations/expectations/core/expect_column_values_to_be_in_type_list.py', 85)
# ('great_expectations/expectations/metrics/column_map_metrics/column_value_lengths.py', 85)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_in_type_list.py', 85)
# ('great_expectations/profile/columns_exist.py', 85)
# ('great_expectations/validation_operators/types/validation_operator_result.py', 85)
# ('great_expectations/checkpoint/checkpoint.py', 86)
# ('great_expectations/datasource/data_connector/data_connector.py', 86)
# ('great_expectations/datasource/datasource.py', 86)
# ('great_expectations/execution_engine/pandas_execution_engine.py', 86)
# ('great_expectations/execution_engine/sparkdf_execution_engine.py', 86)
# ('great_expectations/rule_based_profiler/domain_builder/types/domain.py', 86)
# ('great_expectations/validator/exception_info.py', 86)
# ('great_expectations/core/batch_spec.py', 87)
# ('great_expectations/core/expectation_configuration.py', 87)
# ('great_expectations/datasource/data_connector/inferred_asset_azure_data_connector.py', 87)
# ('great_expectations/datasource/data_connector/inferred_asset_sql_data_connector.py', 87)
# ('great_expectations/exceptions/exceptions.py', 87)
# ('great_expectations/expectations/core/expect_table_row_count_to_equal.py', 87)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_unique.py', 87)
# ('great_expectations/render/renderer/site_index_page_renderer.py', 87)
# ('great_expectations/validation_operators/validation_operators.py', 87)
# ('great_expectations/data_asset/data_asset.py', 88)
# ('great_expectations/data_context/data_context.py', 88)
# ('great_expectations/data_context/store/checkpoint_store.py', 88)
# ('great_expectations/execution_engine/execution_engine.py', 88)
# ('great_expectations/expectations/core/expect_compound_columns_to_be_unique.py', 88)
# ('great_expectations/expectations/expectation.py', 88)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_not_match_like_pattern_list.py', 88)
# ('great_expectations/expectations/metrics/column_pair_map_metrics/column_pair_values_greater.py', 88)
# ('great_expectations/render/renderer/column_section_renderer.py', 88)
# ('great_expectations/render/renderer/page_renderer.py', 88)
# ('great_expectations/render/types/__init__.py', 88)
# ('great_expectations/rule_based_profiler/domain_builder/simple_column_suffix_domain_builder.py', 88)
# ('great_expectations/types/__init__.py', 88)
# ('great_expectations/types/base.py', 88)
# ('great_expectations/core/batch.py', 89)
# ('great_expectations/core/expectation_suite.py', 89)
# ('great_expectations/data_context/util.py', 89)
# ('great_expectations/dataset/pandas_dataset.py', 89)
# ('great_expectations/datasource/data_connector/batch_filter.py', 89)
# ('great_expectations/expectations/core/expect_multicolumn_sum_to_equal.py', 89)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_match_regex_list.py', 89)
# ('great_expectations/render/renderer/call_to_action_renderer.py', 89)
# ('great_expectations/render/renderer/site_builder.py', 89)
# ('great_expectations/core/run_identifier.py', 90)
# ('great_expectations/data_asset/file_data_asset.py', 90)
# ('great_expectations/dataset/dataset.py', 90)
# ('great_expectations/datasource/data_connector/sorter/sorter.py', 90)
# ('great_expectations/datasource/sparkdf_datasource.py', 90)
# ('great_expectations/profile/user_configurable_profiler.py', 90)
# ('great_expectations/render/renderer/datasource_new_notebook_renderer.py', 90)
# ('great_expectations/core/usage_statistics/anonymizers/anonymizer.py', 91)
# ('great_expectations/core/usage_statistics/anonymizers/checkpoint_run_anonymizer.py', 91)
# ('great_expectations/core/usage_statistics/schemas.py', 91)
# ('great_expectations/data_context/store/configuration_store.py', 91)
# ('great_expectations/data_context/store/expectations_store.py', 91)
# ('great_expectations/data_context/store/store_backend.py', 91)
# ('great_expectations/datasource/data_connector/configured_asset_sql_data_connector.py', 91)
# ('great_expectations/datasource/data_connector/runtime_data_connector.py', 91)
# ('great_expectations/datasource/data_connector/sorter/date_time_sorter.py', 91)
# ('great_expectations/expectations/core/expect_column_quantile_values_to_be_between.py', 91)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_z_score.py', 91)
# ('great_expectations/expectations/metrics/column_pair_map_metrics/column_pair_values_in_set.py', 91)
# ('great_expectations/profile/base.py', 91)
# ('great_expectations/rule_based_profiler/domain_builder/domain_builder.py', 91)
# ('great_expectations/rule_based_profiler/expectation_configuration_builder/expectation_configuration_builder.py', 91)
# ('great_expectations/rule_based_profiler/parameter_builder/numeric_metric_range_multi_batch_parameter_builder.py', 91)
# ('great_expectations/checkpoint/toolkit.py', 92)
# ('great_expectations/datasource/batch_kwargs_generator/subdir_reader_batch_kwargs_generator.py', 92)
# ('great_expectations/profile/basic_suite_builder_profiler.py', 92)
# ('great_expectations/render/renderer/content_block/exception_list_content_block.py', 92)
# ('great_expectations/render/renderer/slack_renderer.py', 92)
# ('great_expectations/rule_based_profiler/parameter_builder/parameter_container.py', 92)
# ('great_expectations/validator/metric_configuration.py', 92)
# ('great_expectations/checkpoint/configurator.py', 93)
# ('great_expectations/datasource/data_connector/sorter/custom_list_sorter.py', 93)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_match_like_pattern.py', 93)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_not_match_like_pattern.py', 93)
# ('great_expectations/marshmallow__shade/decorators.py', 93)
# ('great_expectations/core/evaluation_parameters.py', 94)
# ('great_expectations/data_context/store/metric_store.py', 94)
# ('great_expectations/data_context/types/base.py', 94)
# ('great_expectations/dataset/util.py', 94)
# ('great_expectations/datasource/data_connector/configured_asset_file_path_data_connector.py', 94)
# ('great_expectations/expectations/metrics/column_aggregate_metric_provider.py', 94)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_in_set.py', 94)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_increasing.py', 94)
# ('great_expectations/expectations/metrics/table_metrics/table_columns.py', 94)
# ('great_expectations/render/renderer/microsoft_teams_renderer.py', 94)
# ('great_expectations/render/renderer/opsgenie_renderer.py', 94)
# ('great_expectations/render/view/view.py', 94)
# ('great_expectations/rule_based_profiler/util.py', 94)
# ('great_expectations/datasource/data_connector/sorter/numeric_sorter.py', 95)
# ('great_expectations/datasource/new_datasource.py', 95)
# ('great_expectations/expectations/core/expect_table_columns_to_match_ordered_list.py', 95)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_decreasing.py', 95)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_match_regex.py', 95)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_not_match_regex.py', 95)
# ('great_expectations/expectations/metrics/metric_provider.py', 95)
# ('great_expectations/render/renderer/profiling_results_overview_section_renderer.py', 95)
# ('great_expectations/rule_based_profiler/expectation_configuration_builder/default_expectation_configuration_builder.py', 95)
# ('great_expectations/core/usage_statistics/anonymizers/expectation_suite_anonymizer.py', 96)
# ('great_expectations/render/renderer/suite_scaffold_notebook_renderer.py', 96)
# ('great_expectations/rule_based_profiler/profiler.py', 96)
# ('great_expectations/core/async_executor.py', 97)
# ('great_expectations/core/usage_statistics/anonymizers/batch_anonymizer.py', 97)
# ('great_expectations/core/usage_statistics/anonymizers/batch_request_anonymizer.py', 97)
# ('great_expectations/datasource/data_connector/asset/asset.py', 97)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_proportion_of_unique_values.py', 97)
# ('great_expectations/expectations/metrics/multicolumn_map_metrics/select_column_values_unique_within_record.py', 97)
# ('great_expectations/render/renderer/checkpoint_new_notebook_renderer.py', 97)
# ('great_expectations/render/util.py', 97)
# ('great_expectations/data_asset/util.py', 98)
# ('great_expectations/datasource/data_connector/file_path_data_connector.py', 98)
# ('great_expectations/expectations/core/expect_table_column_count_to_equal.py', 98)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_distinct_values.py', 98)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_median.py', 98)
# ('great_expectations/render/renderer/v3/suite_profile_notebook_renderer.py', 98)
# ('great_expectations/validator/validation_graph.py', 98)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_histogram.py', 99)
# ('great_expectations/profile/json_schema_profiler.py', 99)
# ('great_expectations/render/renderer/suite_edit_notebook_renderer.py', 99)
# ('great_expectations/render/renderer/v3/suite_edit_notebook_renderer.py', 99)
# ('great_expectations/__init__.py', 100)
# ('great_expectations/checkpoint/__init__.py', 100)
# ('great_expectations/checkpoint/types/__init__.py', 100)
# ('great_expectations/cli/__init__.py', 100)
# ('great_expectations/cli/cli_messages.py', 100)
# ('great_expectations/cli/upgrade_helpers/__init__.py', 100)
# ('great_expectations/cli/v012/__init__.py', 100)
# ('great_expectations/cli/v012/cli_messages.py', 100)
# ('great_expectations/cli/v012/upgrade_helpers/__init__.py', 100)
# ('great_expectations/core/__init__.py', 100)
# ('great_expectations/core/id_dict.py', 100)
# ('great_expectations/core/urn.py', 100)
# ('great_expectations/core/usage_statistics/__init__.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/__init__.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/action_anonymizer.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/batch_kwargs_anonymizer.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/checkpoint_anonymizer.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/data_connector_anonymizer.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/data_docs_site_anonymizer.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/datasource_anonymizer.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/execution_engine_anonymizer.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/site_builder_anonymizer.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/store_anonymizer.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/store_backend_anonymizer.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/types/__init__.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/types/base.py', 100)
# ('great_expectations/core/usage_statistics/anonymizers/validation_operator_anonymizer.py', 100)
# ('great_expectations/data_asset/__init__.py', 100)
# ('great_expectations/data_context/__init__.py', 100)
# ('great_expectations/data_context/store/__init__.py', 100)
# ('great_expectations/data_context/templates.py', 100)
# ('great_expectations/data_context/types/__init__.py', 100)
# ('great_expectations/data_context/types/base_resource_identifiers.py', 100)
# ('great_expectations/datasource/__init__.py', 100)
# ('great_expectations/datasource/batch_kwargs_generator/__init__.py', 100)
# ('great_expectations/datasource/data_connector/__init__.py', 100)
# ('great_expectations/datasource/data_connector/asset/__init__.py', 100)
# ('great_expectations/datasource/data_connector/configured_asset_dbfs_data_connector.py', 100)
# ('great_expectations/datasource/data_connector/configured_asset_filesystem_data_connector.py', 100)
# ('great_expectations/datasource/data_connector/inferred_asset_dbfs_data_connector.py', 100)
# ('great_expectations/datasource/data_connector/inferred_asset_file_path_data_connector.py', 100)
# ('great_expectations/datasource/data_connector/inferred_asset_filesystem_data_connector.py', 100)
# ('great_expectations/datasource/data_connector/sorter/__init__.py', 100)
# ('great_expectations/datasource/simple_sqlalchemy_datasource.py', 100)
# ('great_expectations/datasource/types/__init__.py', 100)
# ('great_expectations/datasource/types/reader_methods.py', 100)
# ('great_expectations/exceptions/__init__.py', 100)
# ('great_expectations/execution_engine/__init__.py', 100)
# ('great_expectations/execution_engine/pandas_batch_data.py', 100)
# ('great_expectations/execution_engine/sparkdf_batch_data.py', 100)
# ('great_expectations/expectations/__init__.py', 100)
# ('great_expectations/expectations/core/__init__.py', 100)
# ('great_expectations/expectations/metrics/__init__.py', 100)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/__init__.py', 100)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_max.py', 100)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_mean.py', 100)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_min.py', 100)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_most_common_value.py', 100)
# ('great_expectations/expectations/metrics/column_aggregate_metrics/column_sum.py', 100)
# ('great_expectations/expectations/metrics/column_map_metrics/__init__.py', 100)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_dateutil_parseable.py', 100)
# ('great_expectations/expectations/metrics/column_map_metrics/column_values_non_null.py', 100)
# ('great_expectations/expectations/metrics/column_pair_map_metrics/__init__.py', 100)
# ('great_expectations/expectations/metrics/column_pair_map_metrics/column_pair_values_equal.py', 100)
# ('great_expectations/expectations/metrics/multicolumn_map_metrics/__init__.py', 100)
# ('great_expectations/expectations/metrics/multicolumn_map_metrics/compound_columns_unique.py', 100)
# ('great_expectations/expectations/metrics/multicolumn_map_metrics/multicolumn_sum_equal.py', 100)
# ('great_expectations/expectations/metrics/table_metric_provider.py', 100)
# ('great_expectations/expectations/metrics/table_metrics/__init__.py', 100)
# ('great_expectations/expectations/metrics/table_metrics/table_column_count.py', 100)
# ('great_expectations/expectations/metrics/table_metrics/table_row_count.py', 100)
# ('great_expectations/expectations/util.py', 100)
# ('great_expectations/marshmallow__shade/__init__.py', 100)
# ('great_expectations/marshmallow__shade/base.py', 100)
# ('great_expectations/marshmallow__shade/types.py', 100)
# ('great_expectations/marshmallow__shade/warnings.py', 100)
# ('great_expectations/profile/__init__.py', 100)
# ('great_expectations/profile/multi_batch_validation_meta_analysis.py', 100)
# ('great_expectations/render/__init__.py', 100)
# ('great_expectations/render/exceptions.py', 100)
# ('great_expectations/render/notebook_assets/__init__.py', 100)
# ('great_expectations/render/notebook_assets/suite_edit/COLUMN_EXPECTATIONS.md', 100)
# ('great_expectations/render/notebook_assets/suite_edit/COLUMN_EXPECTATIONS_HEADER.md', 100)
# ('great_expectations/render/notebook_assets/suite_edit/TABLE_EXPECTATIONS_HEADER.md', 100)
# ('great_expectations/render/notebook_assets/suite_edit/__init__.py', 100)
# ('great_expectations/render/renderer/__init__.py', 100)
# ('great_expectations/render/renderer/content_block/__init__.py', 100)
# ('great_expectations/render/renderer/content_block/bullet_list_content_block.py', 100)
# ('great_expectations/render/renderer/notebook_renderer.py', 100)
# ('great_expectations/render/renderer/renderer.py', 100)
# ('great_expectations/render/v3/__init__.py', 100)
# ('great_expectations/render/v3/notebook_assets/__init__.py', 100)
# ('great_expectations/render/v3/notebook_assets/suite_edit/COLUMN_EXPECTATIONS.md', 100)
# ('great_expectations/render/v3/notebook_assets/suite_edit/COLUMN_EXPECTATIONS_HEADER.md', 100)
# ('great_expectations/render/v3/notebook_assets/suite_edit/TABLE_EXPECTATIONS_HEADER.md', 100)
# ('great_expectations/render/v3/notebook_assets/suite_edit/__init__.py', 100)
# ('great_expectations/render/view/__init__.py', 100)
# ('great_expectations/render/view/templates/markdown.j2', 100)
# ('great_expectations/render/view/templates/markdown_markdown.j2', 100)
# ('great_expectations/render/view/templates/markdown_string_template.j2', 100)
# ('great_expectations/render/view/templates/string_template.j2', 100)
# ('great_expectations/rule_based_profiler/__init__.py', 100)
# ('great_expectations/rule_based_profiler/domain_builder/__init__.py', 100)
# ('great_expectations/rule_based_profiler/domain_builder/column_domain_builder.py', 100)
# ('great_expectations/rule_based_profiler/domain_builder/table_domain_builder.py', 100)
# ('great_expectations/rule_based_profiler/domain_builder/types/__init__.py', 100)
# ('great_expectations/rule_based_profiler/expectation_configuration_builder/__init__.py', 100)
# ('great_expectations/rule_based_profiler/parameter_builder/__init__.py', 100)
# ('great_expectations/rule_based_profiler/parameter_builder/metric_parameter_builder.py', 100)
# ('great_expectations/rule_based_profiler/rule/__init__.py', 100)
# ('great_expectations/rule_based_profiler/rule/rule.py', 100)
# ('great_expectations/self_check/__init__.py', 100)
# ('great_expectations/types/configurations.py', 100)
# ('great_expectations/validation_operators/__init__.py', 100)
# ('great_expectations/validation_operators/types/__init__.py', 100)
# ('great_expectations/validator/__init__.py', 100)

# %%
def aggregate_simple_test_performance(filename):
    pattern = r"(\d*\.\d{2})s (\w+)\s+(tests.+)"
    return _aggregate_test_performance(filename, pattern)

def aggregate_complex_test_performance(filename):
    pattern = r"(\d*\.\d{2})s (\w+)\s+\[[\s\w.?]+\]\s*(tests\..+)"
    return _aggregate_test_performance(filename, pattern)

def _aggregate_test_performance(filename, pattern):
    with open(filename) as f:
        contents = f.read()

    r = re.compile(pattern)
    verb_map = {"setup": 0, "call": 1, "teardown": 2}
    performance_map = {}
    
    for duration, verb, test in r.findall(contents):
        idx = verb_map[verb]
        if test not in performance_map:
            performance_map[test] = [0, 0, 0]
        performance_map[test][idx] += float(duration)
        
    res = [(sum(v), v, k) for k,v in performance_map.items()]
    res.sort(reverse=True)
    print("Slowest Tests:")
    for i, r in enumerate(res[:10]):
        print(f"{i+1}: {r}")
    
    print(f"\nTotal Test Time: {sum(v[0] for v in res)/60:.2f} mins")
    print(f"Average Test Time: {sum(v[0] for v in res)/len(res):.2f} secs")
    print(f"% Above Threshold (0.1s): {len([v[0] for v in res if v[0] > 0.1]) * 100 / len(res):.2f}%")

    return performance_map

# %%
# Compatability 3.8
compatability = aggregate_complex_test_performance("performance/compatability.txt")
# Out:
# Slowest Tests:
# 1: (15.72, [0.0, 15.72, 0.0], 'tests.data_context.store.test_store_backends/test_TupleS3StoreBackend_list_over_1000_keys')
# 2: (10.67, [0.26, 10.41, 0.0], 'tests.profile.test_user_configurable_profiler_v2_batch_kwargs/test_profiler_all_expectation_types')
# 3: (9.64, [0.96, 8.68, 0.0], 'tests.profile.test_user_configurable_profiler_v3_batch_request/test_profiled_dataset_passes_own_validation')
# 4: (9.059999999999999, [0.54, 8.52, 0.0], 'tests.profile.test_user_configurable_profiler_v3_batch_request/test_profiler_all_expectation_types_pandas')
# 5: (8.379999999999999, [0.87, 7.51, 0.0], 'tests.rule_based_profiler.test_profiler_user_workflows/test_bobby_profiler_user_workflow_multi_batch_row_count_range_rule_and_column_ranges_rule_oneshot_sampling_method')
# 6: (7.57, [0.0, 7.57, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/one_multi_batch_request_one_validator.py]')
# 7: (6.92, [1.05, 5.87, 0.0], 'tests.profile.test_user_configurable_profiler_v3_batch_request/test_build_suite_no_config')
# 8: (6.58, [0.0, 6.58, 0.0], 'tests.test_definitions.test_expectations/test_case_runner[PandasDataset/column_distributional_expectations/expect_column_bootstrapped_ks_test_p_value_to_be_greater_than:positive_bimodal_kde_partition]')
# 9: (6.47, [0.0, 6.47, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/multiple_batch_requests_one_validator_multiple_steps.py]')
# 10: (6.46, [1.93, 4.53, 0.0], 'tests.render.test_data_documentation_site_builder/test_configuration_driven_site_builder')
#
# Total Test Time: 8.42 mins
# Average Test Time: 0.20 secs
# % Above Threshold (0.1s): 23.32%

# %%
# Comprehensive 3.8
comprehensive = aggregate_complex_test_performance("performance/comprehensive.txt")
# Out:
# Slowest Tests:
# 1: (49.28, [4.0, 45.28, 0.0], 'tests.profile.test_user_configurable_profiler_v3_batch_request/test_profiler_all_expectation_types_spark[test_backends0]')
# 2: (20.88, [0.0, 20.88, 0.0], 'tests.data_context.store.test_store_backends/test_TupleS3StoreBackend_list_over_1000_keys')
# 3: (14.14, [0.34, 13.8, 0.0], 'tests.profile.test_user_configurable_profiler_v2_batch_kwargs/test_profiler_all_expectation_types')
# 4: (12.02, [0.01, 12.01, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/one_multi_batch_request_one_validator.py]')
# 5: (11.72, [1.15, 10.57, 0.0], 'tests.profile.test_user_configurable_profiler_v3_batch_request/test_profiled_dataset_passes_own_validation')
# 6: (11.27, [0.73, 10.54, 0.0], 'tests.profile.test_user_configurable_profiler_v3_batch_request/test_profiler_all_expectation_types_pandas')
# 7: (10.15, [0.01, 10.14, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/multiple_batch_requests_one_validator_multiple_steps.py]')
# 8: (10.08, [0.01, 10.07, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/multiple_batch_requests_one_validator_one_step.py]')
# 9: (9.92, [0.01, 9.91, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/two_batch_requests_two_validators.py]')
# 10: (9.91, [0.0, 9.91, 0.0], 'tests.test_definitions.test_expectations/test_case_runner[PandasDataset/column_distributional_expectations/expect_column_bootstrapped_ks_test_p_value_to_be_greater_than:positive_bimodal_kde_partition]')
#
# Total Test Time: 19.15 mins
# Average Test Time: 0.20 secs
# % Above Threshold (0.1s): 24.09%

# %%
# Usage Statistics
usage_stats = aggregate_simple_test_performance("performance/usage_stats.txt")
# Out:
# Slowest Tests:
# 1: (2.43, [0.0, 2.43, 0.0], 'tests/integration/usage_statistics/test_integration_usage_statistics.py::test_graceful_failure_with_no_internet')
# 2: (1.04, [0.0, 1.04, 0.0], 'tests/integration/usage_statistics/test_usage_statistics_messages.py::test_usage_statistics_message[data_context.test_yaml_config_32]')
# 3: (0.74, [0.0, 0.74, 0.0], 'tests/integration/usage_statistics/test_usage_stats_common_messages_are_sent_v3api.py::test_common_usage_stats_are_sent_no_mocking')
# 4: (0.58, [0.0, 0.58, 0.0], 'tests/integration/usage_statistics/test_usage_statistics_messages.py::test_usage_statistics_message[cli.checkpoint.script_3]')
# 5: (0.39, [0.0, 0.39, 0.0], 'tests/integration/usage_statistics/test_usage_statistics_messages.py::test_usage_statistics_message[cli.project.upgrade_1]')
# 6: (0.39, [0.0, 0.39, 0.0], 'tests/integration/usage_statistics/test_integration_usage_statistics.py::test_send_malformed_data')
# 7: (0.33, [0.0, 0.33, 0.0], 'tests/integration/usage_statistics/test_usage_statistics_messages.py::test_usage_statistics_message[data_context.test_yaml_config_28]')
# 8: (0.33, [0.0, 0.33, 0.0], 'tests/integration/usage_statistics/test_usage_statistics_messages.py::test_usage_statistics_message[cli.checkpoint.list_4]')
# 9: (0.33, [0.0, 0.33, 0.0], 'tests/integration/usage_statistics/test_usage_statistics_messages.py::test_usage_statistics_message[checkpoint.run_7]')
# 10: (0.29, [0.0, 0.29, 0.0], 'tests/integration/usage_statistics/test_usage_statistics_messages.py::test_usage_statistics_message[data_context.test_yaml_config_9]')
#
# Total Test Time: 0.68 mins
# Average Test Time: 0.18 secs
# % Above Threshold (0.1s): 99.55%

# %%
# MySQL
mysql = aggregate_complex_test_performance("performance/mysql.txt")
# Out:
# Slowest Tests:
# 1: (18.47, [0.0, 18.47, 0.0], 'tests.data_context.store.test_store_backends/test_TupleS3StoreBackend_list_over_1000_keys')
# 2: (12.17, [0.3, 11.87, 0.0], 'tests.profile.test_user_configurable_profiler_v2_batch_kwargs/test_profiler_all_expectation_types')
# 3: (10.040000000000001, [0.98, 9.06, 0.0], 'tests.profile.test_user_configurable_profiler_v3_batch_request/test_profiled_dataset_passes_own_validation')
# 4: (9.690000000000001, [0.63, 9.06, 0.0], 'tests.profile.test_user_configurable_profiler_v3_batch_request/test_profiler_all_expectation_types_pandas')
# 5: (9.61, [0.01, 9.6, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/one_multi_batch_request_one_validator.py]')
# 6: (8.66, [0.01, 8.65, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/multiple_batch_requests_one_validator_one_step.py]')
# 7: (8.61, [0.01, 8.6, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/multiple_batch_requests_one_validator_multiple_steps.py]')
# 8: (8.53, [0.89, 7.64, 0.0], 'tests.rule_based_profiler.test_profiler_user_workflows/test_bobby_profiler_user_workflow_multi_batch_row_count_range_rule_and_column_ranges_rule_oneshot_sampling_method')
# 9: (8.37, [0.01, 8.36, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/common_workflows/pandas_execution_engine_with_gcp_installed.py]')
# 10: (8.35, [0.01, 8.34, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/two_batch_requests_two_validators.py]')
#
# Total Test Time: 11.32 mins
# Average Test Time: 0.14 secs
# % Above Threshold (0.1s): 14.38%

# %%
# MSSQL
mssql = aggregate_complex_test_performance("performance/mssql.txt")
# Out:
# Slowest Tests:
# 1: (23.8, [0.0, 23.8, 0.0], 'tests.data_context.store.test_store_backends/test_TupleS3StoreBackend_list_over_1000_keys')
# 2: (14.92, [0.37, 14.55, 0.0], 'tests.profile.test_user_configurable_profiler_v2_batch_kwargs/test_profiler_all_expectation_types')
# 3: (13.14, [0.79, 12.35, 0.0], 'tests.profile.test_user_configurable_profiler_v3_batch_request/test_profiler_all_expectation_types_pandas')
# 4: (12.61, [1.27, 11.34, 0.0], 'tests.profile.test_user_configurable_profiler_v3_batch_request/test_profiled_dataset_passes_own_validation')
# 5: (11.73, [0.01, 11.72, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/one_multi_batch_request_one_validator.py]')
# 6: (10.97, [0.01, 10.96, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/multiple_batch_requests_one_validator_one_step.py]')
# 7: (10.530000000000001, [1.12, 9.41, 0.0], 'tests.rule_based_profiler.test_profiler_user_workflows/test_bobby_profiler_user_workflow_multi_batch_row_count_range_rule_and_column_ranges_rule_oneshot_sampling_method')
# 8: (10.51, [0.01, 10.5, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/multiple_batch_requests_one_validator_multiple_steps.py]')
# 9: (10.02, [0.01, 10.01, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/fixtures/yellow_tripdata_pandas_fixture/two_batch_requests_two_validators.py]')
# 10: (9.879999999999999, [0.01, 9.87, 0.0], 'tests.integration.test_script_runner/test_integration_tests[tests/integration/common_workflows/pandas_execution_engine_with_gcp_installed.py]')
#
# Total Test Time: 14.20 mins
# Average Test Time: 0.18 secs
# Percentage Above Threshold (0.1s): 14.96%

# %%
# CLI Integration
cli_integration = aggregate_simple_test_performance("performance/cli_integration.txt")
# Out:
# Slowest Tests:
# 1: (12.48, [6.02, 6.46, 0.0], 'tests/cli/test_checkpoint.py::test_checkpoint_run_happy_path_with_successful_validation_spark[test_backends0]')
# 2: (8.31, [0.38, 7.93, 0.0], 'tests/cli/test_suite.py::test_suite_edit_multiple_datasources_with_sql_with_no_additional_args_without_citations_runs_notebook_opens_jupyter[test_backends0]')
# 3: (8.26, [0.32, 7.94, 0.0], 'tests/cli/test_suite.py::test_suite_edit_multiple_datasources_with_no_additional_args_with_citations_runs_notebook_opens_jupyter')
# 4: (8.1, [0.39, 7.71, 0.0], 'tests/cli/test_suite.py::test_suite_edit_multiple_datasources_with_sql_with_no_additional_args_with_citations_runs_notebook_opens_jupyter[test_backends0]')
# 5: (8.01, [0.28, 7.73, 0.0], 'tests/cli/test_suite.py::test_suite_edit_multiple_datasources_with_no_additional_args_without_citations_runs_notebook_opens_jupyter')
# 6: (7.58, [0.23, 7.35, 0.0], 'tests/cli/test_suite.py::test_suite_new_interactive_valid_batch_request_from_json_file_in_notebook_runs_notebook_no_jupyter')
# 7: (7.2, [0.22, 6.98, 0.0], 'tests/cli/test_suite.py::test_suite_new_profile_runs_notebook_opens_jupyter')
# 8: (7.2, [0.22, 6.98, 0.0], 'tests/cli/test_suite.py::test_suite_new_profile_runs_notebook_no_jupyter')
# 9: (6.029999999999999, [0.22, 5.81, 0.0], 'tests/cli/test_suite.py::test_suite_new_non_interactive_with_suite_name_prompted_default_runs_notebook_opens_jupyter')
# 10: (5.970000000000001, [0.44, 5.53, 0.0], 'tests/cli/test_checkpoint.py::test_checkpoint_script_happy_path_executable_failed_validation_pandas')
#
# Total Test Time: 7.66 mins
# Average Test Time: 1.02 secs
# Percentage Above Threshold (0.1s): 79.60%
