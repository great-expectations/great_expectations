# %% [markdown]
# # Hero Experience
# - This Notebook outlines the steps we can take to get a single `Batch` of data and running the `RuleBasedProfiler` on it. It is adopted from the `Bobby` fixture that we have been using in our integration tests.

# %%
import great_expectations as ge
from great_expectations.core.batch import BatchRequest
from great_expectations.core import ExpectationSuite

from great_expectations.rule_based_profiler.config.base import RuleBasedProfilerConfig
from great_expectations.rule_based_profiler.rule_based_profiler import BaseRuleBasedProfiler

from great_expectations.core.yaml_handler import YAMLHandler
from great_expectations.checkpoint.checkpoint import SimpleCheckpoint

# %%
data_context: ge.DataContext = ge.get_context()

# %%
# loading the first 3 months of 2019 Taxi data into our datasource
data_path: str = "../../../../test_sets/taxi_yellow_tripdata_samples/first_3_files"
yaml_handler = YAMLHandler()
datasource_config = {
    "name": "taxi_pandas",
    "class_name": "Datasource",
    "module_name": "great_expectations.datasource",
    "execution_engine": {
        "module_name": "great_expectations.execution_engine",
        "class_name": "PandasExecutionEngine",
    },
    "data_connectors": {
        "monthly": {
            "class_name": "ConfiguredAssetFilesystemDataConnector",
            "base_directory": data_path,
            "assets":{
                "my_reports": {
                    "base_directory": "./",
                    "group_names": ["name", "year", "month"],
                    "pattern": "^(.+)_(\\d.*)-(\\d.*)\\.csv",
                    "module_name": "great_expectations.datasource.data_connector.asset",
                    "class_name": "Asset",
                },          
            },
        },
    },
}

data_context.test_yaml_config(yaml_handler.dump(datasource_config))
# Out:
# Attempting to instantiate class from config...
# 	Instantiating as a Datasource, since class_name is Datasource
# 	Successfully instantiated Datasource
#
#
# ExecutionEngine class name: PandasExecutionEngine
# Data Connectors:
# 	monthly : ConfiguredAssetFilesystemDataConnector
#
# 	Available data_asset_names (1 of 1):
# 		my_reports (3 of 3): ['yellow_tripdata_sample_2019-01.csv', 'yellow_tripdata_sample_2019-02.csv', 'yellow_tripdata_sample_2019-03.csv']
#
# 	Unmatched data_references (1 of 1):['.DS_Store']

# %%
# add_datasource only if it doesn't already exist in our configuration
try:
    data_context.get_datasource(datasource_config["name"])
except ValueError:
    data_context.add_datasource(**datasource_config)

# %% [markdown]
# ## Build BatchRequest and Retrieve Batch
# In this example, we will be using a `BatchRequest` that returns a single `Batch`, namely the most recent 2019 taxi data asset in our `Asset`.

# %%
hero_batch: BatchRequest = BatchRequest(
    datasource_name="taxi_pandas",
    data_connector_name="monthly",
    data_asset_name="my_reports",
    data_connector_query={
      "index": "-1"
    }
)

# %%
expectation_suite = data_context.create_expectation_suite(
    expectation_suite_name="temp_suite", overwrite_existing=True
)

# %%
validator = data_context.get_validator(
    batch_request=hero_batch,
    expectation_suite=expectation_suite,
)

# %%
validator.head(n_rows=5, fetch_all=False)
# Out:
# Calculating Metrics: 100%|██████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 57.82it/s]
#    vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# 0          1  2019-03-01 18:43:31  2019-03-01 18:48:42                2
# 1          2  2019-03-20 16:30:11  2019-03-20 16:44:49                1
# 2          1  2019-03-07 19:01:51  2019-03-07 19:04:36                1
# 3          1  2019-03-02 16:33:01  2019-03-02 16:37:41                1
# 4          2  2019-03-28 14:10:47  2019-03-28 14:49:37                1
#
#    trip_distance  rate_code_id store_and_fwd_flag  pickup_location_id  \
# 0           1.10             1                  N                 143
# 1           2.63             1                  N                 231
# 2           0.30             1                  N                 237
# 3           0.90             1                  N                  42
# 4          15.68             3                  N                 231
#
#    dropoff_location_id  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  238             1          6.0    3.5      0.5        1.55
# 1                   88             1         12.5    1.0      0.5        3.36
# 2                  237             1          4.0    3.5      0.5        1.66
# 3                   41             1          5.5    0.0      0.5        0.00
# 4                    1             1         63.0    0.0      0.0       14.76
#
#    tolls_amount  improvement_surcharge  total_amount  congestion_surcharge
# 0           0.0                    0.3         11.85                   2.5
# 1           0.0                    0.3         20.16                   2.5
# 2           0.0                    0.3          9.96                   2.5
# 3           0.0                    0.3          6.30                   0.0
# 4          10.5                    0.3         88.56                   0.0

# %% [markdown]
# # Load Profiler

# %%
# this part will be taken care of by the Data Assistants

# %%
configuration_path = "../bobby_user_workflow_verbose_profiler_config.yml"

# %%
with open(configuration_path) as f:
    read = f.read()
    yaml_config = yaml_handler.load(read)

# %%
yaml_config
# Out:
# {'name': 'bobby user workflow',
#  'class_name': 'RuleBaseProfiler',
#  'config_version': 1.0,
#  'variables': {'jan_feb_2019_monthly_tripdata_batch_request': {'datasource_name': 'taxi_pandas',
#    'data_connector_name': 'monthly',
#    'data_asset_name': 'my_reports',
#    'data_connector_query': {'index': ':-1'}},
#   'estimator': 'oneshot',
#   'false_positive_rate': 0.01,
#   'mostly': 1.0},
#  'rules': {'row_count_range_rule': {'domain_builder': {'class_name': 'TableDomainBuilder'},
#    'parameter_builders': [{'name': 'row_count_range',
#      'class_name': 'NumericMetricRangeMultiBatchParameterBuilder',
#      'batch_request': '$variables.jan_feb_2019_monthly_tripdata_batch_request',
#      'metric_name': 'table.row_count',
#      'estimator': '$variables.estimator',
#      'false_positive_rate': '$variables.false_positive_rate',
#      'round_decimals': 0,
#      'truncate_values': {'lower_bound': 0}}],
#    'expectation_configuration_builders': [{'expectation_type': 'expect_table_row_count_to_be_between',
#      'class_name': 'DefaultExpectationConfigurationBuilder',
#      'module_name': 'great_expectations.rule_based_profiler.expectation_configuration_builder',
#      'min_value': '$parameter.row_count_range.value[0]',
#      'max_value': '$parameter.row_count_range.value[1]',
#      'meta': {'profiler_details': '$parameter.row_count_range.details'}}]},
#   'column_ranges_rule': {'domain_builder': {'class_name': 'ColumnDomainBuilder',
#     'batch_request': {'datasource_name': 'taxi_pandas',
#      'data_connector_name': 'monthly',
#      'data_asset_name': 'my_reports',
#      'data_connector_query': {'index': -1}},
#     'include_semantic_types': ['numeric']},
#    'parameter_builders': [{'name': 'min_range',
#      'class_name': 'NumericMetricRangeMultiBatchParameterBuilder',
#      'batch_request': '$variables.jan_feb_2019_monthly_tripdata_batch_request',
#      'metric_name': 'column.min',
#      'metric_domain_kwargs': '$domain.domain_kwargs',
#      'estimator': '$variables.estimator',
#      'false_positive_rate': '$variables.false_positive_rate',
#      'round_decimals': 2},
#     {'name': 'max_range',
#      'class_name': 'NumericMetricRangeMultiBatchParameterBuilder',
#      'batch_request': '$variables.jan_feb_2019_monthly_tripdata_batch_request',
#      'metric_name': 'column.max',
#      'metric_domain_kwargs': '$domain.domain_kwargs',
#      'estimator': '$variables.estimator',
#      'false_positive_rate': '$variables.false_positive_rate',
#      'round_decimals': 2}],
#    'expectation_configuration_builders': [{'expectation_type': 'expect_column_min_to_be_between',
#      'class_name': 'DefaultExpectationConfigurationBuilder',
#      'module_name': 'great_expectations.rule_based_profiler.expectation_configuration_builder',
#      'column': '$domain.domain_kwargs.column',
#      'min_value': '$parameter.min_range.value[0]',
#      'max_value': '$parameter.min_range.value[1]',
#      'mostly': '$variables.mostly',
#      'meta': {'profiler_details': '$parameter.min_range.details'}},
#     {'expectation_type': 'expect_column_max_to_be_between',
#      'class_name': 'DefaultExpectationConfigurationBuilder',
#      'module_name': 'great_expectations.rule_based_profiler.expectation_configuration_builder',
#      'column': '$domain.domain_kwargs.column',
#      'min_value': '$parameter.max_range.value[0]',
#      'max_value': '$parameter.max_range.value[1]',
#      'mostly': '$variables.mostly',
#      'meta': {'profiler_details': '$parameter.max_range.details'}}]}}}

# %%
profiler_configuration: RuleBasedProfilerConfig = RuleBasedProfilerConfig(**yaml_config)

# %%
profiler: BaseRuleBasedProfiler = BaseRuleBasedProfiler(
    profiler_configuration,
    data_context=data_context,
)

# %%
expectation_suite: ExpectationSuite = profiler.run(
    expectation_suite_name="NewExpectationSuite",
    batch_request=hero_batch,
    include_citation=True,
)
# Out:
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 268.68it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 125.68it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 124.89it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 285.37it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 298.76it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 335.15it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 304.10it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 291.12it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 299.33it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 307.27it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 314.28it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 193.59it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 288.73it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 295.28it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 265.91it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 300.68it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 321.13it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 282.77it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 313.58it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 274.72it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 323.05it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 299.18it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 278.84it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 269.73it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 240.41it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 301.90it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 302.33it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 316.56it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 307.86it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 284.51it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 316.13it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 297.85it/s]
# Calculating Metrics: 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 326.59it/s]

# %%
expectation_suite
# Out:
# {
#   "expectation_suite_name": "NewExpectationSuite",
#   "expectations": [
#     {
#       "kwargs": {
#         "min_value": 10000.0,
#         "max_value": 10000.0
#       },
#       "expectation_type": "expect_table_row_count_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "table.row_count",
#             "domain_kwargs": {},
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "vendor_id",
#         "min_value": 1.0,
#         "max_value": 1.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "vendor_id"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "vendor_id",
#         "min_value": 4.0,
#         "max_value": 4.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "vendor_id"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "passenger_count",
#         "min_value": 0.0,
#         "max_value": 1.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "passenger_count"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "passenger_count",
#         "min_value": 6.0,
#         "max_value": 6.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "passenger_count"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "trip_distance",
#         "min_value": 0.0,
#         "max_value": 0.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "trip_distance"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "trip_distance",
#         "min_value": 37.62,
#         "max_value": 57.85,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "trip_distance"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "rate_code_id",
#         "min_value": 1.0,
#         "max_value": 1.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "rate_code_id"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "rate_code_id",
#         "min_value": 5.0,
#         "max_value": 99.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "rate_code_id"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "pickup_location_id",
#         "min_value": 1.0,
#         "max_value": 1.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "pickup_location_id"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "pickup_location_id",
#         "min_value": 265.0,
#         "max_value": 265.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "pickup_location_id"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "dropoff_location_id",
#         "min_value": 1.0,
#         "max_value": 1.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "dropoff_location_id"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "dropoff_location_id",
#         "min_value": 265.0,
#         "max_value": 265.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "dropoff_location_id"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "payment_type",
#         "min_value": 1.0,
#         "max_value": 1.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "payment_type"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "payment_type",
#         "min_value": 4.0,
#         "max_value": 4.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "payment_type"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "fare_amount",
#         "min_value": -51.84,
#         "max_value": -21.16,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "fare_amount"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "fare_amount",
#         "min_value": 228.94,
#         "max_value": 2990.05,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "fare_amount"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "extra",
#         "min_value": -36.53,
#         "max_value": -1.18,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "extra"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "extra",
#         "min_value": 4.51,
#         "max_value": 6.99,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "extra"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "mta_tax",
#         "min_value": -0.5,
#         "max_value": -0.5,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "mta_tax"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "mta_tax",
#         "min_value": 0.69,
#         "max_value": 37.32,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "mta_tax"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "tip_amount",
#         "min_value": 0.0,
#         "max_value": 0.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "tip_amount"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "tip_amount",
#         "min_value": 46.84,
#         "max_value": 74.86,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "tip_amount"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "tolls_amount",
#         "min_value": 0.0,
#         "max_value": 0.0,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "tolls_amount"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "tolls_amount",
#         "min_value": 26.4,
#         "max_value": 497.67,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "tolls_amount"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "improvement_surcharge",
#         "min_value": -0.3,
#         "max_value": -0.3,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "improvement_surcharge"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "improvement_surcharge",
#         "min_value": 0.3,
#         "max_value": 0.3,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "improvement_surcharge"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "total_amount",
#         "min_value": -52.66,
#         "max_value": -24.44,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "total_amount"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "total_amount",
#         "min_value": 550.18,
#         "max_value": 2992.47,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "total_amount"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "congestion_surcharge",
#         "min_value": -2.49,
#         "max_value": -0.01,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_min_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.min",
#             "domain_kwargs": {
#               "column": "congestion_surcharge"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     },
#     {
#       "kwargs": {
#         "column": "congestion_surcharge",
#         "min_value": 0.01,
#         "max_value": 2.49,
#         "mostly": 1.0
#       },
#       "expectation_type": "expect_column_max_to_be_between",
#       "meta": {
#         "profiler_details": {
#           "metric_configuration": {
#             "metric_name": "column.max",
#             "domain_kwargs": {
#               "column": "congestion_surcharge"
#             },
#             "metric_value_kwargs": null,
#             "metric_dependencies": null
#           },
#           "num_batches": 2
#         }
#       }
#     }
#   ],
#   "meta": {
#     "great_expectations_version": "0.14.12+16.g1ff8673.dirty",
#     "citations": [
#       {
#         "citation_date": "2022-03-26T00:55:52.909776Z",
#         "profiler_config": {
#           "name": "bobby user workflow",
#           "config_version": 1.0,
#           "variables": {
#             "jan_feb_2019_monthly_tripdata_batch_request": {
#               "datasource_name": "taxi_pandas",
#               "data_connector_name": "monthly",
#               "data_asset_name": "my_reports",
#               "data_connector_query": {
#                 "index": ":-1"
#               }
#             },
#             "estimator": "oneshot",
#             "false_positive_rate": 0.01,
#             "mostly": 1.0
#           },
#           "rules": {
#             "row_count_range_rule": {
#               "domain_builder": {
#                 "class_name": "TableDomainBuilder"
#               },
#               "parameter_builders": [
#                 {
#                   "name": "row_count_range",
#                   "class_name": "NumericMetricRangeMultiBatchParameterBuilder",
#                   "batch_request": "$variables.jan_feb_2019_monthly_tripdata_batch_request",
#                   "metric_name": "table.row_count",
#                   "estimator": "$variables.estimator",
#                   "false_positive_rate": "$variables.false_positive_rate",
#                   "round_decimals": 0,
#                   "truncate_values": {
#                     "lower_bound": 0
#                   }
#                 }
#               ],
#               "expectation_configuration_builders": [
#                 {
#                   "expectation_type": "expect_table_row_count_to_be_between",
#                   "class_name": "DefaultExpectationConfigurationBuilder",
#                   "module_name": "great_expectations.rule_based_profiler.expectation_configuration_builder",
#                   "min_value": "$parameter.row_count_range.value[0]",
#                   "max_value": "$parameter.row_count_range.value[1]",
#                   "meta": {
#                     "profiler_details": "$parameter.row_count_range.details"
#                   }
#                 }
#               ]
#             },
#             "column_ranges_rule": {
#               "domain_builder": {
#                 "class_name": "ColumnDomainBuilder",
#                 "batch_request": {
#                   "datasource_name": "taxi_pandas",
#                   "data_connector_name": "monthly",
#                   "data_asset_name": "my_reports",
#                   "data_connector_query": {
#                     "index": -1
#                   }
#                 },
#                 "include_semantic_types": [
#                   "numeric"
#                 ]
#               },
#               "parameter_builders": [
#                 {
#                   "name": "min_range",
#                   "class_name": "NumericMetricRangeMultiBatchParameterBuilder",
#                   "batch_request": "$variables.jan_feb_2019_monthly_tripdata_batch_request",
#                   "metric_name": "column.min",
#                   "metric_domain_kwargs": "$domain.domain_kwargs",
#                   "estimator": "$variables.estimator",
#                   "false_positive_rate": "$variables.false_positive_rate",
#                   "round_decimals": 2
#                 },
#                 {
#                   "name": "max_range",
#                   "class_name": "NumericMetricRangeMultiBatchParameterBuilder",
#                   "batch_request": "$variables.jan_feb_2019_monthly_tripdata_batch_request",
#                   "metric_name": "column.max",
#                   "metric_domain_kwargs": "$domain.domain_kwargs",
#                   "estimator": "$variables.estimator",
#                   "false_positive_rate": "$variables.false_positive_rate",
#                   "round_decimals": 2
#                 }
#               ],
#               "expectation_configuration_builders": [
#                 {
#                   "expectation_type": "expect_column_min_to_be_between",
#                   "class_name": "DefaultExpectationConfigurationBuilder",
#                   "module_name": "great_expectations.rule_based_profiler.expectation_configuration_builder",
#                   "column": "$domain.domain_kwargs.column",
#                   "min_value": "$parameter.min_range.value[0]",
#                   "max_value": "$parameter.min_range.value[1]",
#                   "mostly": "$variables.mostly",
#                   "meta": {
#                     "profiler_details": "$parameter.min_range.details"
#                   }
#                 },
#                 {
#                   "expectation_type": "expect_column_max_to_be_between",
#                   "class_name": "DefaultExpectationConfigurationBuilder",
#                   "module_name": "great_expectations.rule_based_profiler.expectation_configuration_builder",
#                   "column": "$domain.domain_kwargs.column",
#                   "min_value": "$parameter.max_range.value[0]",
#                   "max_value": "$parameter.max_range.value[1]",
#                   "mostly": "$variables.mostly",
#                   "meta": {
#                     "profiler_details": "$parameter.max_range.details"
#                   }
#                 }
#               ]
#             }
#           }
#         },
#         "comment": "Suite created by Rule-Based Profiler with the configuration included."
#       }
#     ]
#   },
#   "ge_cloud_id": null,
#   "data_asset_type": null
# }

# %%
# TODO : output of which Expectations are being included?

# %%
data_context.save_expectation_suite(expectation_suite)
# Out:
# '/Users/work/Development/great_expectations/tests/test_fixtures/rule_based_profiler/example_notebooks/great_expectations/expectations/NewExpectationSuite.json'

# %% [markdown]
# # Use Profiled ExpectationSuite to run Checkpoint

# %%
checkpoint: SimpleCheckpoint = SimpleCheckpoint(
    data_context=data_context,
    name="hero_checkpoint",
    validations=[{
         "batch_request": hero_batch,
         "expectation_suite_name": "NewExpectationSuite"
    }]
)

# %%
results = checkpoint.run()
# Out:
# Calculating Metrics: 100%|███████████████████████████████████████████████████████████████| 33/33 [00:00<00:00, 485.50it/s]

# %%
data_context.build_data_docs()
# Out:
# {'local_site': 'file:///Users/work/Development/great_expectations/tests/test_fixtures/rule_based_profiler/example_notebooks/great_expectations/uncommitted/data_docs/local_site/index.html'}
