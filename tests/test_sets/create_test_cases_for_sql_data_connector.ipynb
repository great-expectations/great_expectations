# %%
import random
import datetime
from hashlib import md5
import sqlite3

import pandas as pd

# %%
# ! test_cases_for_sql_data_connector.db

# %%
filename = "test_cases_for_sql_data_connector_new.db"
db = sqlite3.connect(filename)

# %%
def generate_ascending_list_of_datetimes(
    k,
    start_date=datetime.date(2020,1,1),
    end_date=datetime.date(2020,12,31)
):
    start_time = datetime.datetime(start_date.year, start_date.month, start_date.day)
    days_between_dates = (end_date - start_date).total_seconds()
    
    datetime_list = [start_time + datetime.timedelta(seconds=random.randrange(days_between_dates)) for i in range(k)]
    datetime_list.sort()
    return datetime_list

generate_ascending_list_of_datetimes(10)
# Out:
# [datetime.datetime(2020, 1, 8, 18, 0, 45),
#  datetime.datetime(2020, 2, 4, 14, 55, 58),
#  datetime.datetime(2020, 2, 28, 2, 6, 4),
#  datetime.datetime(2020, 3, 31, 19, 1, 2),
#  datetime.datetime(2020, 4, 11, 12, 8, 39),
#  datetime.datetime(2020, 6, 3, 19, 0, 36),
#  datetime.datetime(2020, 9, 7, 16, 23, 31),
#  datetime.datetime(2020, 10, 14, 3, 14, 50),
#  datetime.datetime(2020, 12, 7, 0, 57, 30),
#  datetime.datetime(2020, 12, 30, 4, 41, 16)]

# %%
k = 120
random.seed(1)

timestamp_list = generate_ascending_list_of_datetimes(k, end_date=datetime.date(2020,1,31))
date_list = [datetime.date(ts.year, ts.month, ts.day) for ts in timestamp_list]

batch_ids = [random.randint(0,10) for i in range(k)]
batch_ids.sort()

session_ids = [random.randint(2,60) for i in range(k)]
session_ids.sort()
session_ids = [i-random.randint(0,2) for i in session_ids]

events_df = pd.DataFrame({
    "id" : range(k),
    "batch_id" : batch_ids,
    "date" : date_list,
    "y" : [d.year for d in date_list],
    "m" : [d.month for d in date_list],
    "d" : [d.day for d in date_list],
    "timestamp" : timestamp_list,
    "session_id" : session_ids,
    "event_type" : [random.choice(["start", "stop", "continue"]) for i in range(k)],
    "favorite_color" : ["#"+"".join([random.choice(list("0123456789ABCDEF")) for j in range(6)]) for i in range(k)]
})

# NOTE: in this fake example, id, batch_id, date, and timestamp are all sorted in strictly the same order
# This would not necessarily be true in the real world.
# Events might arrive and be indexed out of order.
# Batches might not correspond strictly with units in time.
# etc.

# events_df.to_sql("events_df", db)

# %%
events_df[["id", "date", "event_type", "favorite_color"]].to_sql("table_partitioned_by_date_column__A", db)

# %%
events_df[["id", "timestamp", "event_type", "favorite_color"]].to_sql("table_partitioned_by_timestamp_column__B", db)

# %%
df = events_df[["id", "event_type", "favorite_color"]].to_sql("table_partitioned_by_regularly_spaced_incrementing_id_column__C", db)

# %%
events_df[["id", "event_type", "favorite_color"]].to_sql("table_partitioned_by_irregularly_spaced_incrementing_id_with_spacing_in_a_second_table__D", db)
lookup_df = events_df.groupby("date").id.min()
lookup_df.to_sql("table_containing_id_spacers_for_D", db)

# %%
events_df[["id", "batch_id", "event_type", "favorite_color"]].to_sql("table_partitioned_by_incrementing_batch_id__E", db)

# %%
events_df[["id", "session_id", "event_type", "favorite_color"]].to_sql("table_partitioned_by_foreign_key__F", db)
sessions_df = events_df.groupby("date").id.min()
sessions_df.to_sql("table_with_fk_reference_from_F", db)

# %%
events_df[["id", "y", "m", "d", "event_type", "favorite_color"]].to_sql("table_partitioned_by_multiple_columns__G", db)

# %%
events_df[["id", "event_type", "favorite_color"]].to_sql("table_that_should_be_partitioned_by_random_hash__H", db)

# %%
events_df.to_sql("table_full__I", db)

# %% [markdown]
# ## Add Views

# %%
db_cursor = db.cursor()

# %%
db_cursor.execute("CREATE VIEW view_by_date_column__A AS SELECT id, date, event_type, favorite_color FROM table_full__I")

# %%
db_cursor.execute("CREATE VIEW view_by_timestamp_column__B AS SELECT id, timestamp, event_type, favorite_color FROM table_full__I")

# %%
db_cursor.execute("CREATE VIEW view_by_regularly_spaced_incrementing_id_column__C AS SELECT id, event_type, favorite_color FROM table_full__I")

# %%
db_cursor.execute("CREATE VIEW view_by_irregularly_spaced_incrementing_id_with_spacing_in_a_second_table__D AS SELECT id, event_type, favorite_color FROM table_full__I")

# %%
db_cursor.execute("CREATE VIEW view_containing_id_spacers_for_D AS SELECT id, batch_id, event_type, favorite_color FROM table_full__I")

# %%
db_cursor.execute("CREATE VIEW view_by_incrementing_batch_id__E AS SELECT id, batch_id, event_type, favorite_color FROM table_full__I")

# %%
db_cursor.execute("CREATE VIEW view_partitioned_by_foreign_key__F AS SELECT id, session_id, event_type, favorite_color FROM table_full__I")

# %%
db_cursor.execute("CREATE VIEW view_with_fk_reference_from_F AS SELECT id, date FROM table_full__I GROUP BY date")

# %%
db_cursor.execute("CREATE VIEW view_by_multiple_columns__G AS SELECT id, y, m, d, event_type, favorite_color FROM table_full__I")

# %%
db_cursor.execute("CREATE VIEW view_that_should_be_partitioned_by_random_hash__H AS SELECT id, event_type, favorite_color FROM table_full__I")

# %% [markdown]
# ## Test if Views Work

# %%
db_cursor.execute("SELECT * FROM view_by_date_column__A;")
rows = db_cursor.fetchall()

for row in rows: 
    print(row)
# Out:
# (0, '2020-01-01', 'start', '#23C548')
# (1, '2020-01-01', 'start', '#D61FCB')
# (2, '2020-01-01', 'start', '#C51283')
# (3, '2020-01-01', 'start', '#8242E7')
# (4, '2020-01-02', 'stop', '#CDC5AE')
# (5, '2020-01-02', 'stop', '#4F63DD')
# (6, '2020-01-02', 'start', '#3987C0')
# (7, '2020-01-02', 'continue', '#6E0078')
# (8, '2020-01-02', 'continue', '#659468')
# (9, '2020-01-02', 'continue', '#98E5BF')
# (10, '2020-01-02', 'stop', '#D36C69')
# (11, '2020-01-02', 'start', '#303094')
# (12, '2020-01-03', 'start', '#2B9DBA')
# (13, '2020-01-03', 'start', '#03EEB9')
# (14, '2020-01-04', 'continue', '#CAF3CC')
# (15, '2020-01-05', 'continue', '#6086ED')
# (16, '2020-01-05', 'start', '#95E6B0')
# (17, '2020-01-05', 'stop', '#CDCA2F')
# (18, '2020-01-05', 'continue', '#790D4C')
# (19, '2020-01-06', 'continue', '#8520B8')
# (20, '2020-01-06', 'continue', '#D94E8F')
# (21, '2020-01-06', 'continue', '#5E183D')
# (22, '2020-01-07', 'continue', '#2B2E05')
# (23, '2020-01-07', 'start', '#52C896')
# (24, '2020-01-08', 'start', '#67A822')
# (25, '2020-01-09', 'stop', '#BE1598')
# (26, '2020-01-09', 'stop', '#B7CC5F')
# (27, '2020-01-09', 'continue', '#8A7870')
# (28, '2020-01-10', 'start', '#CAD786')
# (29, '2020-01-10', 'start', '#25E48E')
# (30, '2020-01-10', 'continue', '#544EB9')
# (31, '2020-01-10', 'continue', '#C73692')
# (32, '2020-01-10', 'start', '#37CAF3')
# (33, '2020-01-11', 'stop', '#511061')
# (34, '2020-01-11', 'start', '#FEA835')
# (35, '2020-01-11', 'continue', '#37C7FE')
# (36, '2020-01-11', 'stop', '#C5779E')
# (37, '2020-01-12', 'stop', '#C6E8AF')
# (38, '2020-01-12', 'continue', '#362100')
# (39, '2020-01-12', 'stop', '#FAC96C')
# (40, '2020-01-12', 'continue', '#5400C4')
# (41, '2020-01-12', 'stop', '#1C842E')
# (42, '2020-01-12', 'continue', '#901141')
# (43, '2020-01-13', 'stop', '#83D260')
# (44, '2020-01-13', 'start', '#F486EC')
# (45, '2020-01-14', 'stop', '#A88771')
# (46, '2020-01-14', 'stop', '#5BD1BD')
# (47, '2020-01-15', 'start', '#6D2828')
# (48, '2020-01-15', 'stop', '#53416D')
# (49, '2020-01-15', 'stop', '#112FB3')
# (50, '2020-01-15', 'start', '#A141E4')
# (51, '2020-01-16', 'continue', '#CE0828')
# (52, '2020-01-17', 'stop', '#A291C1')
# (53, '2020-01-17', 'continue', '#8A48C3')
# (54, '2020-01-17', 'start', '#93D76A')
# (55, '2020-01-18', 'start', '#ACF34E')
# (56, '2020-01-18', 'continue', '#0956BC')
# (57, '2020-01-18', 'stop', '#A3DB42')
# (58, '2020-01-18', 'continue', '#19AD9A')
# (59, '2020-01-19', 'start', '#B8A034')
# (60, '2020-01-19', 'continue', '#AAA2E8')
# (61, '2020-01-19', 'start', '#FEBC21')
# (62, '2020-01-19', 'start', '#41F87A')
# (63, '2020-01-19', 'stop', '#BBC9EA')
# (64, '2020-01-20', 'stop', '#504874')
# (65, '2020-01-20', 'stop', '#35D138')
# (66, '2020-01-20', 'continue', '#368222')
# (67, '2020-01-20', 'stop', '#65D0BF')
# (68, '2020-01-20', 'start', '#976F7D')
# (69, '2020-01-21', 'continue', '#EB6F28')
# (70, '2020-01-21', 'start', '#D60CF2')
# (71, '2020-01-21', 'start', '#CD1BE0')
# (72, '2020-01-21', 'stop', '#69039A')
# (73, '2020-01-21', 'start', '#9DD9E9')
# (74, '2020-01-22', 'start', '#4E4580')
# (75, '2020-01-22', 'continue', '#D1BDC9')
# (76, '2020-01-22', 'stop', '#0220C8')
# (77, '2020-01-22', 'continue', '#E8BFAC')
# (78, '2020-01-22', 'continue', '#E3FB4D')
# (79, '2020-01-23', 'stop', '#4058B4')
# (80, '2020-01-23', 'continue', '#9D89D8')
# (81, '2020-01-23', 'continue', '#DAF6FC')
# (82, '2020-01-23', 'continue', '#D22464')
# (83, '2020-01-24', 'start', '#70384F')
# (84, '2020-01-24', 'start', '#3C502D')
# (85, '2020-01-24', 'stop', '#16DB13')
# (86, '2020-01-24', 'stop', '#D3885F')
# (87, '2020-01-25', 'continue', '#162C3E')
# (88, '2020-01-25', 'stop', '#9FC3F3')
# (89, '2020-01-25', 'start', '#4C658D')
# (90, '2020-01-25', 'continue', '#9F6AF3')
# (91, '2020-01-25', 'stop', '#0B81E9')
# (92, '2020-01-25', 'stop', '#37887D')
# (93, '2020-01-25', 'continue', '#4486D1')
# (94, '2020-01-25', 'continue', '#4D88F9')
# (95, '2020-01-25', 'continue', '#8F6FBF')
# (96, '2020-01-25', 'continue', '#7A55E4')
# (97, '2020-01-26', 'stop', '#1A46AF')
# (98, '2020-01-26', 'continue', '#FA3448')
# (99, '2020-01-26', 'start', '#721537')
# (100, '2020-01-27', 'start', '#69DA00')
# (101, '2020-01-27', 'start', '#97278A')
# (102, '2020-01-27', 'continue', '#8C03AB')
# (103, '2020-01-27', 'continue', '#43841B')
# (104, '2020-01-27', 'stop', '#2239A7')
# (105, '2020-01-27', 'start', '#81B024')
# (106, '2020-01-27', 'continue', '#CB73A8')
# (107, '2020-01-28', 'start', '#0A3B48')
# (108, '2020-01-28', 'stop', '#C2FDC9')
# (109, '2020-01-28', 'stop', '#794135')
# (110, '2020-01-28', 'continue', '#76D808')
# (111, '2020-01-29', 'stop', '#88F4C3')
# (112, '2020-01-29', 'continue', '#B2B09E')
# (113, '2020-01-29', 'stop', '#44246F')
# (114, '2020-01-29', 'start', '#AB954C')
# (115, '2020-01-29', 'continue', '#EC3489')
# (116, '2020-01-29', 'continue', '#004C3E')
# (117, '2020-01-30', 'continue', '#0DD8BD')
# (118, '2020-01-30', 'stop', '#CE13F1')
# (119, '2020-01-30', 'continue', '#0134B8')

# %%
db_cursor.execute("SELECT * FROM view_by_timestamp_column__B;")
rows = db_cursor.fetchall()
for row in rows: 
    print(row)
# Out:
# (0, '2020-01-01 02:27:13', 'start', '#23C548')
# (1, '2020-01-01 06:39:05', 'start', '#D61FCB')
# (2, '2020-01-01 10:43:28', 'start', '#C51283')
# (3, '2020-01-01 14:19:56', 'start', '#8242E7')
# (4, '2020-01-02 01:02:14', 'stop', '#CDC5AE')
# (5, '2020-01-02 02:00:25', 'stop', '#4F63DD')
# (6, '2020-01-02 05:38:47', 'start', '#3987C0')
# (7, '2020-01-02 09:01:37', 'continue', '#6E0078')
# (8, '2020-01-02 09:50:05', 'continue', '#659468')
# (9, '2020-01-02 10:27:26', 'continue', '#98E5BF')
# (10, '2020-01-02 11:38:23', 'stop', '#D36C69')
# (11, '2020-01-02 16:13:31', 'start', '#303094')
# (12, '2020-01-03 02:39:58', 'start', '#2B9DBA')
# (13, '2020-01-03 17:23:18', 'start', '#03EEB9')
# (14, '2020-01-04 01:31:29', 'continue', '#CAF3CC')
# (15, '2020-01-05 04:44:31', 'continue', '#6086ED')
# (16, '2020-01-05 13:21:15', 'start', '#95E6B0')
# (17, '2020-01-05 20:30:31', 'stop', '#CDCA2F')
# (18, '2020-01-05 23:06:11', 'continue', '#790D4C')
# (19, '2020-01-06 05:44:56', 'continue', '#8520B8')
# (20, '2020-01-06 17:23:06', 'continue', '#D94E8F')
# (21, '2020-01-06 20:50:49', 'continue', '#5E183D')
# (22, '2020-01-07 06:35:11', 'continue', '#2B2E05')
# (23, '2020-01-07 12:32:44', 'start', '#52C896')
# (24, '2020-01-08 22:43:20', 'start', '#67A822')
# (25, '2020-01-09 04:25:35', 'stop', '#BE1598')
# (26, '2020-01-09 06:28:16', 'stop', '#B7CC5F')
# (27, '2020-01-09 09:34:05', 'continue', '#8A7870')
# (28, '2020-01-10 00:35:47', 'start', '#CAD786')
# (29, '2020-01-10 05:11:27', 'start', '#25E48E')
# (30, '2020-01-10 16:27:12', 'continue', '#544EB9')
# (31, '2020-01-10 16:49:47', 'continue', '#C73692')
# (32, '2020-01-10 23:24:27', 'start', '#37CAF3')
# (33, '2020-01-11 04:36:54', 'stop', '#511061')
# (34, '2020-01-11 12:21:23', 'start', '#FEA835')
# (35, '2020-01-11 14:53:54', 'continue', '#37C7FE')
# (36, '2020-01-11 18:17:22', 'stop', '#C5779E')
# (37, '2020-01-12 00:24:04', 'stop', '#C6E8AF')
# (38, '2020-01-12 02:31:38', 'continue', '#362100')
# (39, '2020-01-12 04:58:44', 'stop', '#FAC96C')
# (40, '2020-01-12 06:30:17', 'continue', '#5400C4')
# (41, '2020-01-12 07:33:47', 'stop', '#1C842E')
# (42, '2020-01-12 18:48:45', 'continue', '#901141')
# (43, '2020-01-13 09:10:37', 'stop', '#83D260')
# (44, '2020-01-13 22:17:51', 'start', '#F486EC')
# (45, '2020-01-14 01:43:59', 'stop', '#A88771')
# (46, '2020-01-14 19:04:10', 'stop', '#5BD1BD')
# (47, '2020-01-15 01:37:12', 'start', '#6D2828')
# (48, '2020-01-15 09:19:11', 'stop', '#53416D')
# (49, '2020-01-15 17:26:59', 'stop', '#112FB3')
# (50, '2020-01-15 23:27:46', 'start', '#A141E4')
# (51, '2020-01-16 09:49:56', 'continue', '#CE0828')
# (52, '2020-01-17 03:37:04', 'stop', '#A291C1')
# (53, '2020-01-17 16:35:10', 'continue', '#8A48C3')
# (54, '2020-01-17 18:46:12', 'start', '#93D76A')
# (55, '2020-01-18 03:35:39', 'start', '#ACF34E')
# (56, '2020-01-18 16:56:53', 'continue', '#0956BC')
# (57, '2020-01-18 19:43:48', 'stop', '#A3DB42')
# (58, '2020-01-18 23:41:24', 'continue', '#19AD9A')
# (59, '2020-01-19 04:33:38', 'start', '#B8A034')
# (60, '2020-01-19 10:17:01', 'continue', '#AAA2E8')
# (61, '2020-01-19 12:08:06', 'start', '#FEBC21')
# (62, '2020-01-19 15:01:50', 'start', '#41F87A')
# (63, '2020-01-19 22:09:36', 'stop', '#BBC9EA')
# (64, '2020-01-20 02:10:31', 'stop', '#504874')
# (65, '2020-01-20 02:17:24', 'stop', '#35D138')
# (66, '2020-01-20 02:34:36', 'continue', '#368222')
# (67, '2020-01-20 15:01:47', 'stop', '#65D0BF')
# (68, '2020-01-20 15:13:26', 'start', '#976F7D')
# (69, '2020-01-21 02:42:38', 'continue', '#EB6F28')
# (70, '2020-01-21 04:53:05', 'start', '#D60CF2')
# (71, '2020-01-21 11:47:25', 'start', '#CD1BE0')
# (72, '2020-01-21 11:48:05', 'stop', '#69039A')
# (73, '2020-01-21 16:25:53', 'start', '#9DD9E9')
# (74, '2020-01-22 00:12:36', 'start', '#4E4580')
# (75, '2020-01-22 06:10:33', 'continue', '#D1BDC9')
# (76, '2020-01-22 07:25:38', 'stop', '#0220C8')
# (77, '2020-01-22 14:54:49', 'continue', '#E8BFAC')
# (78, '2020-01-22 19:41:42', 'continue', '#E3FB4D')
# (79, '2020-01-23 06:55:38', 'stop', '#4058B4')
# (80, '2020-01-23 07:28:36', 'continue', '#9D89D8')
# (81, '2020-01-23 18:47:51', 'continue', '#DAF6FC')
# (82, '2020-01-23 22:12:20', 'continue', '#D22464')
# (83, '2020-01-24 07:30:17', 'start', '#70384F')
# (84, '2020-01-24 08:31:27', 'start', '#3C502D')
# (85, '2020-01-24 16:23:39', 'stop', '#16DB13')
# (86, '2020-01-24 18:32:03', 'stop', '#D3885F')
# (87, '2020-01-25 01:13:25', 'continue', '#162C3E')
# (88, '2020-01-25 01:39:47', 'stop', '#9FC3F3')
# (89, '2020-01-25 05:47:56', 'start', '#4C658D')
# (90, '2020-01-25 07:28:26', 'continue', '#9F6AF3')
# (91, '2020-01-25 09:09:01', 'stop', '#0B81E9')
# (92, '2020-01-25 12:41:53', 'stop', '#37887D')
# (93, '2020-01-25 15:32:00', 'continue', '#4486D1')
# (94, '2020-01-25 16:21:35', 'continue', '#4D88F9')
# (95, '2020-01-25 21:06:20', 'continue', '#8F6FBF')
# (96, '2020-01-25 22:35:14', 'continue', '#7A55E4')
# (97, '2020-01-26 04:18:14', 'stop', '#1A46AF')
# (98, '2020-01-26 06:56:14', 'continue', '#FA3448')
# (99, '2020-01-26 14:43:58', 'start', '#721537')
# (100, '2020-01-27 04:41:59', 'start', '#69DA00')
# (101, '2020-01-27 06:47:28', 'start', '#97278A')
# (102, '2020-01-27 14:27:43', 'continue', '#8C03AB')
# (103, '2020-01-27 14:51:38', 'continue', '#43841B')
# (104, '2020-01-27 15:23:48', 'stop', '#2239A7')
# (105, '2020-01-27 20:07:41', 'start', '#81B024')
# (106, '2020-01-27 21:55:27', 'continue', '#CB73A8')
# (107, '2020-01-28 00:18:58', 'start', '#0A3B48')
# (108, '2020-01-28 06:01:45', 'stop', '#C2FDC9')
# (109, '2020-01-28 15:10:14', 'stop', '#794135')
# (110, '2020-01-28 16:05:50', 'continue', '#76D808')
# (111, '2020-01-29 01:10:47', 'stop', '#88F4C3')
# (112, '2020-01-29 01:37:25', 'continue', '#B2B09E')
# (113, '2020-01-29 12:34:51', 'stop', '#44246F')
# (114, '2020-01-29 14:14:14', 'start', '#AB954C')
# (115, '2020-01-29 16:44:37', 'continue', '#EC3489')
# (116, '2020-01-29 19:06:32', 'continue', '#004C3E')
# (117, '2020-01-30 11:42:59', 'continue', '#0DD8BD')
# (118, '2020-01-30 13:28:19', 'stop', '#CE13F1')
# (119, '2020-01-30 20:18:23', 'continue', '#0134B8')

# %%
db_cursor.execute("SELECT * FROM view_by_regularly_spaced_incrementing_id_column__C;")
rows = db_cursor.fetchall()
for row in rows: 
    print(row)
# Out:
# (0, 'start', '#23C548')
# (1, 'start', '#D61FCB')
# (2, 'start', '#C51283')
# (3, 'start', '#8242E7')
# (4, 'stop', '#CDC5AE')
# (5, 'stop', '#4F63DD')
# (6, 'start', '#3987C0')
# (7, 'continue', '#6E0078')
# (8, 'continue', '#659468')
# (9, 'continue', '#98E5BF')
# (10, 'stop', '#D36C69')
# (11, 'start', '#303094')
# (12, 'start', '#2B9DBA')
# (13, 'start', '#03EEB9')
# (14, 'continue', '#CAF3CC')
# (15, 'continue', '#6086ED')
# (16, 'start', '#95E6B0')
# (17, 'stop', '#CDCA2F')
# (18, 'continue', '#790D4C')
# (19, 'continue', '#8520B8')
# (20, 'continue', '#D94E8F')
# (21, 'continue', '#5E183D')
# (22, 'continue', '#2B2E05')
# (23, 'start', '#52C896')
# (24, 'start', '#67A822')
# (25, 'stop', '#BE1598')
# (26, 'stop', '#B7CC5F')
# (27, 'continue', '#8A7870')
# (28, 'start', '#CAD786')
# (29, 'start', '#25E48E')
# (30, 'continue', '#544EB9')
# (31, 'continue', '#C73692')
# (32, 'start', '#37CAF3')
# (33, 'stop', '#511061')
# (34, 'start', '#FEA835')
# (35, 'continue', '#37C7FE')
# (36, 'stop', '#C5779E')
# (37, 'stop', '#C6E8AF')
# (38, 'continue', '#362100')
# (39, 'stop', '#FAC96C')
# (40, 'continue', '#5400C4')
# (41, 'stop', '#1C842E')
# (42, 'continue', '#901141')
# (43, 'stop', '#83D260')
# (44, 'start', '#F486EC')
# (45, 'stop', '#A88771')
# (46, 'stop', '#5BD1BD')
# (47, 'start', '#6D2828')
# (48, 'stop', '#53416D')
# (49, 'stop', '#112FB3')
# (50, 'start', '#A141E4')
# (51, 'continue', '#CE0828')
# (52, 'stop', '#A291C1')
# (53, 'continue', '#8A48C3')
# (54, 'start', '#93D76A')
# (55, 'start', '#ACF34E')
# (56, 'continue', '#0956BC')
# (57, 'stop', '#A3DB42')
# (58, 'continue', '#19AD9A')
# (59, 'start', '#B8A034')
# (60, 'continue', '#AAA2E8')
# (61, 'start', '#FEBC21')
# (62, 'start', '#41F87A')
# (63, 'stop', '#BBC9EA')
# (64, 'stop', '#504874')
# (65, 'stop', '#35D138')
# (66, 'continue', '#368222')
# (67, 'stop', '#65D0BF')
# (68, 'start', '#976F7D')
# (69, 'continue', '#EB6F28')
# (70, 'start', '#D60CF2')
# (71, 'start', '#CD1BE0')
# (72, 'stop', '#69039A')
# (73, 'start', '#9DD9E9')
# (74, 'start', '#4E4580')
# (75, 'continue', '#D1BDC9')
# (76, 'stop', '#0220C8')
# (77, 'continue', '#E8BFAC')
# (78, 'continue', '#E3FB4D')
# (79, 'stop', '#4058B4')
# (80, 'continue', '#9D89D8')
# (81, 'continue', '#DAF6FC')
# (82, 'continue', '#D22464')
# (83, 'start', '#70384F')
# (84, 'start', '#3C502D')
# (85, 'stop', '#16DB13')
# (86, 'stop', '#D3885F')
# (87, 'continue', '#162C3E')
# (88, 'stop', '#9FC3F3')
# (89, 'start', '#4C658D')
# (90, 'continue', '#9F6AF3')
# (91, 'stop', '#0B81E9')
# (92, 'stop', '#37887D')
# (93, 'continue', '#4486D1')
# (94, 'continue', '#4D88F9')
# (95, 'continue', '#8F6FBF')
# (96, 'continue', '#7A55E4')
# (97, 'stop', '#1A46AF')
# (98, 'continue', '#FA3448')
# (99, 'start', '#721537')
# (100, 'start', '#69DA00')
# (101, 'start', '#97278A')
# (102, 'continue', '#8C03AB')
# (103, 'continue', '#43841B')
# (104, 'stop', '#2239A7')
# (105, 'start', '#81B024')
# (106, 'continue', '#CB73A8')
# (107, 'start', '#0A3B48')
# (108, 'stop', '#C2FDC9')
# (109, 'stop', '#794135')
# (110, 'continue', '#76D808')
# (111, 'stop', '#88F4C3')
# (112, 'continue', '#B2B09E')
# (113, 'stop', '#44246F')
# (114, 'start', '#AB954C')
# (115, 'continue', '#EC3489')
# (116, 'continue', '#004C3E')
# (117, 'continue', '#0DD8BD')
# (118, 'stop', '#CE13F1')
# (119, 'continue', '#0134B8')

# %%
db_cursor.execute("SELECT * FROM view_by_regularly_spaced_incrementing_id_column__C;")
rows = db_cursor.fetchall()
for row in rows: 
    print(row)
# Out:
# (0, 'start', '#23C548')
# (1, 'start', '#D61FCB')
# (2, 'start', '#C51283')
# (3, 'start', '#8242E7')
# (4, 'stop', '#CDC5AE')
# (5, 'stop', '#4F63DD')
# (6, 'start', '#3987C0')
# (7, 'continue', '#6E0078')
# (8, 'continue', '#659468')
# (9, 'continue', '#98E5BF')
# (10, 'stop', '#D36C69')
# (11, 'start', '#303094')
# (12, 'start', '#2B9DBA')
# (13, 'start', '#03EEB9')
# (14, 'continue', '#CAF3CC')
# (15, 'continue', '#6086ED')
# (16, 'start', '#95E6B0')
# (17, 'stop', '#CDCA2F')
# (18, 'continue', '#790D4C')
# (19, 'continue', '#8520B8')
# (20, 'continue', '#D94E8F')
# (21, 'continue', '#5E183D')
# (22, 'continue', '#2B2E05')
# (23, 'start', '#52C896')
# (24, 'start', '#67A822')
# (25, 'stop', '#BE1598')
# (26, 'stop', '#B7CC5F')
# (27, 'continue', '#8A7870')
# (28, 'start', '#CAD786')
# (29, 'start', '#25E48E')
# (30, 'continue', '#544EB9')
# (31, 'continue', '#C73692')
# (32, 'start', '#37CAF3')
# (33, 'stop', '#511061')
# (34, 'start', '#FEA835')
# (35, 'continue', '#37C7FE')
# (36, 'stop', '#C5779E')
# (37, 'stop', '#C6E8AF')
# (38, 'continue', '#362100')
# (39, 'stop', '#FAC96C')
# (40, 'continue', '#5400C4')
# (41, 'stop', '#1C842E')
# (42, 'continue', '#901141')
# (43, 'stop', '#83D260')
# (44, 'start', '#F486EC')
# (45, 'stop', '#A88771')
# (46, 'stop', '#5BD1BD')
# (47, 'start', '#6D2828')
# (48, 'stop', '#53416D')
# (49, 'stop', '#112FB3')
# (50, 'start', '#A141E4')
# (51, 'continue', '#CE0828')
# (52, 'stop', '#A291C1')
# (53, 'continue', '#8A48C3')
# (54, 'start', '#93D76A')
# (55, 'start', '#ACF34E')
# (56, 'continue', '#0956BC')
# (57, 'stop', '#A3DB42')
# (58, 'continue', '#19AD9A')
# (59, 'start', '#B8A034')
# (60, 'continue', '#AAA2E8')
# (61, 'start', '#FEBC21')
# (62, 'start', '#41F87A')
# (63, 'stop', '#BBC9EA')
# (64, 'stop', '#504874')
# (65, 'stop', '#35D138')
# (66, 'continue', '#368222')
# (67, 'stop', '#65D0BF')
# (68, 'start', '#976F7D')
# (69, 'continue', '#EB6F28')
# (70, 'start', '#D60CF2')
# (71, 'start', '#CD1BE0')
# (72, 'stop', '#69039A')
# (73, 'start', '#9DD9E9')
# (74, 'start', '#4E4580')
# (75, 'continue', '#D1BDC9')
# (76, 'stop', '#0220C8')
# (77, 'continue', '#E8BFAC')
# (78, 'continue', '#E3FB4D')
# (79, 'stop', '#4058B4')
# (80, 'continue', '#9D89D8')
# (81, 'continue', '#DAF6FC')
# (82, 'continue', '#D22464')
# (83, 'start', '#70384F')
# (84, 'start', '#3C502D')
# (85, 'stop', '#16DB13')
# (86, 'stop', '#D3885F')
# (87, 'continue', '#162C3E')
# (88, 'stop', '#9FC3F3')
# (89, 'start', '#4C658D')
# (90, 'continue', '#9F6AF3')
# (91, 'stop', '#0B81E9')
# (92, 'stop', '#37887D')
# (93, 'continue', '#4486D1')
# (94, 'continue', '#4D88F9')
# (95, 'continue', '#8F6FBF')
# (96, 'continue', '#7A55E4')
# (97, 'stop', '#1A46AF')
# (98, 'continue', '#FA3448')
# (99, 'start', '#721537')
# (100, 'start', '#69DA00')
# (101, 'start', '#97278A')
# (102, 'continue', '#8C03AB')
# (103, 'continue', '#43841B')
# (104, 'stop', '#2239A7')
# (105, 'start', '#81B024')
# (106, 'continue', '#CB73A8')
# (107, 'start', '#0A3B48')
# (108, 'stop', '#C2FDC9')
# (109, 'stop', '#794135')
# (110, 'continue', '#76D808')
# (111, 'stop', '#88F4C3')
# (112, 'continue', '#B2B09E')
# (113, 'stop', '#44246F')
# (114, 'start', '#AB954C')
# (115, 'continue', '#EC3489')
# (116, 'continue', '#004C3E')
# (117, 'continue', '#0DD8BD')
# (118, 'stop', '#CE13F1')
# (119, 'continue', '#0134B8')

# %%
db_cursor.execute("SELECT * FROM view_by_irregularly_spaced_incrementing_id_with_spacing_in_a_second_table__D;")
rows = db_cursor.fetchall()
for row in rows: 
    print(row)
# Out:
# (0, 'start', '#23C548')
# (1, 'start', '#D61FCB')
# (2, 'start', '#C51283')
# (3, 'start', '#8242E7')
# (4, 'stop', '#CDC5AE')
# (5, 'stop', '#4F63DD')
# (6, 'start', '#3987C0')
# (7, 'continue', '#6E0078')
# (8, 'continue', '#659468')
# (9, 'continue', '#98E5BF')
# (10, 'stop', '#D36C69')
# (11, 'start', '#303094')
# (12, 'start', '#2B9DBA')
# (13, 'start', '#03EEB9')
# (14, 'continue', '#CAF3CC')
# (15, 'continue', '#6086ED')
# (16, 'start', '#95E6B0')
# (17, 'stop', '#CDCA2F')
# (18, 'continue', '#790D4C')
# (19, 'continue', '#8520B8')
# (20, 'continue', '#D94E8F')
# (21, 'continue', '#5E183D')
# (22, 'continue', '#2B2E05')
# (23, 'start', '#52C896')
# (24, 'start', '#67A822')
# (25, 'stop', '#BE1598')
# (26, 'stop', '#B7CC5F')
# (27, 'continue', '#8A7870')
# (28, 'start', '#CAD786')
# (29, 'start', '#25E48E')
# (30, 'continue', '#544EB9')
# (31, 'continue', '#C73692')
# (32, 'start', '#37CAF3')
# (33, 'stop', '#511061')
# (34, 'start', '#FEA835')
# (35, 'continue', '#37C7FE')
# (36, 'stop', '#C5779E')
# (37, 'stop', '#C6E8AF')
# (38, 'continue', '#362100')
# (39, 'stop', '#FAC96C')
# (40, 'continue', '#5400C4')
# (41, 'stop', '#1C842E')
# (42, 'continue', '#901141')
# (43, 'stop', '#83D260')
# (44, 'start', '#F486EC')
# (45, 'stop', '#A88771')
# (46, 'stop', '#5BD1BD')
# (47, 'start', '#6D2828')
# (48, 'stop', '#53416D')
# (49, 'stop', '#112FB3')
# (50, 'start', '#A141E4')
# (51, 'continue', '#CE0828')
# (52, 'stop', '#A291C1')
# (53, 'continue', '#8A48C3')
# (54, 'start', '#93D76A')
# (55, 'start', '#ACF34E')
# (56, 'continue', '#0956BC')
# (57, 'stop', '#A3DB42')
# (58, 'continue', '#19AD9A')
# (59, 'start', '#B8A034')
# (60, 'continue', '#AAA2E8')
# (61, 'start', '#FEBC21')
# (62, 'start', '#41F87A')
# (63, 'stop', '#BBC9EA')
# (64, 'stop', '#504874')
# (65, 'stop', '#35D138')
# (66, 'continue', '#368222')
# (67, 'stop', '#65D0BF')
# (68, 'start', '#976F7D')
# (69, 'continue', '#EB6F28')
# (70, 'start', '#D60CF2')
# (71, 'start', '#CD1BE0')
# (72, 'stop', '#69039A')
# (73, 'start', '#9DD9E9')
# (74, 'start', '#4E4580')
# (75, 'continue', '#D1BDC9')
# (76, 'stop', '#0220C8')
# (77, 'continue', '#E8BFAC')
# (78, 'continue', '#E3FB4D')
# (79, 'stop', '#4058B4')
# (80, 'continue', '#9D89D8')
# (81, 'continue', '#DAF6FC')
# (82, 'continue', '#D22464')
# (83, 'start', '#70384F')
# (84, 'start', '#3C502D')
# (85, 'stop', '#16DB13')
# (86, 'stop', '#D3885F')
# (87, 'continue', '#162C3E')
# (88, 'stop', '#9FC3F3')
# (89, 'start', '#4C658D')
# (90, 'continue', '#9F6AF3')
# (91, 'stop', '#0B81E9')
# (92, 'stop', '#37887D')
# (93, 'continue', '#4486D1')
# (94, 'continue', '#4D88F9')
# (95, 'continue', '#8F6FBF')
# (96, 'continue', '#7A55E4')
# (97, 'stop', '#1A46AF')
# (98, 'continue', '#FA3448')
# (99, 'start', '#721537')
# (100, 'start', '#69DA00')
# (101, 'start', '#97278A')
# (102, 'continue', '#8C03AB')
# (103, 'continue', '#43841B')
# (104, 'stop', '#2239A7')
# (105, 'start', '#81B024')
# (106, 'continue', '#CB73A8')
# (107, 'start', '#0A3B48')
# (108, 'stop', '#C2FDC9')
# (109, 'stop', '#794135')
# (110, 'continue', '#76D808')
# (111, 'stop', '#88F4C3')
# (112, 'continue', '#B2B09E')
# (113, 'stop', '#44246F')
# (114, 'start', '#AB954C')
# (115, 'continue', '#EC3489')
# (116, 'continue', '#004C3E')
# (117, 'continue', '#0DD8BD')
# (118, 'stop', '#CE13F1')
# (119, 'continue', '#0134B8')

# %%
db_cursor.execute("SELECT * FROM view_by_incrementing_batch_id__E;")
rows = db_cursor.fetchall()
for row in rows: 
    print(row)
# Out:
# (0, 0, 'start', '#23C548')
# (1, 0, 'start', '#D61FCB')
# (2, 0, 'start', '#C51283')
# (3, 0, 'start', '#8242E7')
# (4, 0, 'stop', '#CDC5AE')
# (5, 0, 'stop', '#4F63DD')
# (6, 0, 'start', '#3987C0')
# (7, 0, 'continue', '#6E0078')
# (8, 0, 'continue', '#659468')
# (9, 0, 'continue', '#98E5BF')
# (10, 0, 'stop', '#D36C69')
# (11, 0, 'start', '#303094')
# (12, 0, 'start', '#2B9DBA')
# (13, 0, 'start', '#03EEB9')
# (14, 0, 'continue', '#CAF3CC')
# (15, 1, 'continue', '#6086ED')
# (16, 1, 'start', '#95E6B0')
# (17, 1, 'stop', '#CDCA2F')
# (18, 1, 'continue', '#790D4C')
# (19, 1, 'continue', '#8520B8')
# (20, 1, 'continue', '#D94E8F')
# (21, 1, 'continue', '#5E183D')
# (22, 1, 'continue', '#2B2E05')
# (23, 1, 'start', '#52C896')
# (24, 2, 'start', '#67A822')
# (25, 2, 'stop', '#BE1598')
# (26, 2, 'stop', '#B7CC5F')
# (27, 2, 'continue', '#8A7870')
# (28, 2, 'start', '#CAD786')
# (29, 2, 'start', '#25E48E')
# (30, 2, 'continue', '#544EB9')
# (31, 2, 'continue', '#C73692')
# (32, 2, 'start', '#37CAF3')
# (33, 2, 'stop', '#511061')
# (34, 2, 'start', '#FEA835')
# (35, 2, 'continue', '#37C7FE')
# (36, 3, 'stop', '#C5779E')
# (37, 3, 'stop', '#C6E8AF')
# (38, 3, 'continue', '#362100')
# (39, 3, 'stop', '#FAC96C')
# (40, 3, 'continue', '#5400C4')
# (41, 3, 'stop', '#1C842E')
# (42, 3, 'continue', '#901141')
# (43, 3, 'stop', '#83D260')
# (44, 3, 'start', '#F486EC')
# (45, 4, 'stop', '#A88771')
# (46, 4, 'stop', '#5BD1BD')
# (47, 4, 'start', '#6D2828')
# (48, 4, 'stop', '#53416D')
# (49, 4, 'stop', '#112FB3')
# (50, 4, 'start', '#A141E4')
# (51, 4, 'continue', '#CE0828')
# (52, 4, 'stop', '#A291C1')
# (53, 4, 'continue', '#8A48C3')
# (54, 4, 'start', '#93D76A')
# (55, 4, 'start', '#ACF34E')
# (56, 4, 'continue', '#0956BC')
# (57, 4, 'stop', '#A3DB42')
# (58, 4, 'continue', '#19AD9A')
# (59, 4, 'start', '#B8A034')
# (60, 5, 'continue', '#AAA2E8')
# (61, 5, 'start', '#FEBC21')
# (62, 5, 'start', '#41F87A')
# (63, 5, 'stop', '#BBC9EA')
# (64, 5, 'stop', '#504874')
# (65, 5, 'stop', '#35D138')
# (66, 5, 'continue', '#368222')
# (67, 6, 'stop', '#65D0BF')
# (68, 6, 'start', '#976F7D')
# (69, 6, 'continue', '#EB6F28')
# (70, 6, 'start', '#D60CF2')
# (71, 6, 'start', '#CD1BE0')
# (72, 6, 'stop', '#69039A')
# (73, 6, 'start', '#9DD9E9')
# (74, 6, 'start', '#4E4580')
# (75, 6, 'continue', '#D1BDC9')
# (76, 6, 'stop', '#0220C8')
# (77, 7, 'continue', '#E8BFAC')
# (78, 7, 'continue', '#E3FB4D')
# (79, 7, 'stop', '#4058B4')
# (80, 7, 'continue', '#9D89D8')
# (81, 7, 'continue', '#DAF6FC')
# (82, 7, 'continue', '#D22464')
# (83, 7, 'start', '#70384F')
# (84, 7, 'start', '#3C502D')
# (85, 7, 'stop', '#16DB13')
# (86, 8, 'stop', '#D3885F')
# (87, 8, 'continue', '#162C3E')
# (88, 8, 'stop', '#9FC3F3')
# (89, 8, 'start', '#4C658D')
# (90, 8, 'continue', '#9F6AF3')
# (91, 8, 'stop', '#0B81E9')
# (92, 8, 'stop', '#37887D')
# (93, 8, 'continue', '#4486D1')
# (94, 8, 'continue', '#4D88F9')
# (95, 8, 'continue', '#8F6FBF')
# (96, 8, 'continue', '#7A55E4')
# (97, 8, 'stop', '#1A46AF')
# (98, 8, 'continue', '#FA3448')
# (99, 9, 'start', '#721537')
# (100, 9, 'start', '#69DA00')
# (101, 9, 'start', '#97278A')
# (102, 9, 'continue', '#8C03AB')
# (103, 9, 'continue', '#43841B')
# (104, 9, 'stop', '#2239A7')
# (105, 9, 'start', '#81B024')
# (106, 9, 'continue', '#CB73A8')
# (107, 9, 'start', '#0A3B48')
# (108, 9, 'stop', '#C2FDC9')
# (109, 9, 'stop', '#794135')
# (110, 10, 'continue', '#76D808')
# (111, 10, 'stop', '#88F4C3')
# (112, 10, 'continue', '#B2B09E')
# (113, 10, 'stop', '#44246F')
# (114, 10, 'start', '#AB954C')
# (115, 10, 'continue', '#EC3489')
# (116, 10, 'continue', '#004C3E')
# (117, 10, 'continue', '#0DD8BD')
# (118, 10, 'stop', '#CE13F1')
# (119, 10, 'continue', '#0134B8')

# %%
db_cursor.execute("SELECT * FROM view_partitioned_by_foreign_key__F;")
rows = db_cursor.fetchall()
for row in rows: 
    print(row)
# Out:
# (0, 3, 'start', '#23C548')
# (1, 2, 'start', '#D61FCB')
# (2, 4, 'start', '#C51283')
# (3, 2, 'start', '#8242E7')
# (4, 4, 'stop', '#CDC5AE')
# (5, 6, 'stop', '#4F63DD')
# (6, 6, 'start', '#3987C0')
# (7, 6, 'continue', '#6E0078')
# (8, 7, 'continue', '#659468')
# (9, 8, 'continue', '#98E5BF')
# (10, 8, 'stop', '#D36C69')
# (11, 8, 'start', '#303094')
# (12, 6, 'start', '#2B9DBA')
# (13, 7, 'start', '#03EEB9')
# (14, 9, 'continue', '#CAF3CC')
# (15, 9, 'continue', '#6086ED')
# (16, 8, 'start', '#95E6B0')
# (17, 10, 'stop', '#CDCA2F')
# (18, 8, 'continue', '#790D4C')
# (19, 10, 'continue', '#8520B8')
# (20, 10, 'continue', '#D94E8F')
# (21, 9, 'continue', '#5E183D')
# (22, 12, 'continue', '#2B2E05')
# (23, 11, 'start', '#52C896')
# (24, 11, 'start', '#67A822')
# (25, 12, 'stop', '#BE1598')
# (26, 13, 'stop', '#B7CC5F')
# (27, 12, 'continue', '#8A7870')
# (28, 14, 'start', '#CAD786')
# (29, 13, 'start', '#25E48E')
# (30, 14, 'continue', '#544EB9')
# (31, 15, 'continue', '#C73692')
# (32, 17, 'start', '#37CAF3')
# (33, 17, 'stop', '#511061')
# (34, 16, 'start', '#FEA835')
# (35, 18, 'continue', '#37C7FE')
# (36, 19, 'stop', '#C5779E')
# (37, 19, 'stop', '#C6E8AF')
# (38, 19, 'continue', '#362100')
# (39, 19, 'stop', '#FAC96C')
# (40, 18, 'continue', '#5400C4')
# (41, 18, 'stop', '#1C842E')
# (42, 19, 'continue', '#901141')
# (43, 21, 'stop', '#83D260')
# (44, 21, 'start', '#F486EC')
# (45, 21, 'stop', '#A88771')
# (46, 22, 'stop', '#5BD1BD')
# (47, 23, 'start', '#6D2828')
# (48, 23, 'stop', '#53416D')
# (49, 22, 'stop', '#112FB3')
# (50, 21, 'start', '#A141E4')
# (51, 23, 'continue', '#CE0828')
# (52, 24, 'stop', '#A291C1')
# (53, 24, 'continue', '#8A48C3')
# (54, 25, 'start', '#93D76A')
# (55, 24, 'start', '#ACF34E')
# (56, 24, 'continue', '#0956BC')
# (57, 24, 'stop', '#A3DB42')
# (58, 25, 'continue', '#19AD9A')
# (59, 24, 'start', '#B8A034')
# (60, 26, 'continue', '#AAA2E8')
# (61, 27, 'start', '#FEBC21')
# (62, 29, 'start', '#41F87A')
# (63, 27, 'stop', '#BBC9EA')
# (64, 31, 'stop', '#504874')
# (65, 32, 'stop', '#35D138')
# (66, 33, 'continue', '#368222')
# (67, 33, 'stop', '#65D0BF')
# (68, 32, 'start', '#976F7D')
# (69, 34, 'continue', '#EB6F28')
# (70, 33, 'start', '#D60CF2')
# (71, 36, 'start', '#CD1BE0')
# (72, 35, 'stop', '#69039A')
# (73, 36, 'start', '#9DD9E9')
# (74, 34, 'start', '#4E4580')
# (75, 35, 'continue', '#D1BDC9')
# (76, 35, 'stop', '#0220C8')
# (77, 36, 'continue', '#E8BFAC')
# (78, 38, 'continue', '#E3FB4D')
# (79, 37, 'stop', '#4058B4')
# (80, 37, 'continue', '#9D89D8')
# (81, 38, 'continue', '#DAF6FC')
# (82, 37, 'continue', '#D22464')
# (83, 39, 'start', '#70384F')
# (84, 38, 'start', '#3C502D')
# (85, 37, 'stop', '#16DB13')
# (86, 39, 'stop', '#D3885F')
# (87, 40, 'continue', '#162C3E')
# (88, 40, 'stop', '#9FC3F3')
# (89, 41, 'start', '#4C658D')
# (90, 42, 'continue', '#9F6AF3')
# (91, 43, 'stop', '#0B81E9')
# (92, 43, 'stop', '#37887D')
# (93, 43, 'continue', '#4486D1')
# (94, 47, 'continue', '#4D88F9')
# (95, 48, 'continue', '#8F6FBF')
# (96, 50, 'continue', '#7A55E4')
# (97, 51, 'stop', '#1A46AF')
# (98, 51, 'continue', '#FA3448')
# (99, 50, 'start', '#721537')
# (100, 52, 'start', '#69DA00')
# (101, 51, 'start', '#97278A')
# (102, 50, 'continue', '#8C03AB')
# (103, 53, 'continue', '#43841B')
# (104, 53, 'stop', '#2239A7')
# (105, 55, 'start', '#81B024')
# (106, 55, 'continue', '#CB73A8')
# (107, 53, 'start', '#0A3B48')
# (108, 56, 'stop', '#C2FDC9')
# (109, 56, 'stop', '#794135')
# (110, 56, 'continue', '#76D808')
# (111, 56, 'stop', '#88F4C3')
# (112, 57, 'continue', '#B2B09E')
# (113, 58, 'stop', '#44246F')
# (114, 59, 'start', '#AB954C')
# (115, 57, 'continue', '#EC3489')
# (116, 58, 'continue', '#004C3E')
# (117, 59, 'continue', '#0DD8BD')
# (118, 58, 'stop', '#CE13F1')
# (119, 58, 'continue', '#0134B8')

# %%
db_cursor.execute("SELECT * FROM view_with_fk_reference_from_F;")
rows = db_cursor.fetchall()
for row in rows: 
    print(row)
# Out:
# (0, '2020-01-01')
# (4, '2020-01-02')
# (12, '2020-01-03')
# (14, '2020-01-04')
# (15, '2020-01-05')
# (19, '2020-01-06')
# (22, '2020-01-07')
# (24, '2020-01-08')
# (25, '2020-01-09')
# (28, '2020-01-10')
# (33, '2020-01-11')
# (37, '2020-01-12')
# (43, '2020-01-13')
# (45, '2020-01-14')
# (47, '2020-01-15')
# (51, '2020-01-16')
# (52, '2020-01-17')
# (55, '2020-01-18')
# (59, '2020-01-19')
# (64, '2020-01-20')
# (69, '2020-01-21')
# (74, '2020-01-22')
# (79, '2020-01-23')
# (83, '2020-01-24')
# (87, '2020-01-25')
# (97, '2020-01-26')
# (100, '2020-01-27')
# (107, '2020-01-28')
# (111, '2020-01-29')
# (117, '2020-01-30')

# %%
db_cursor.execute("SELECT * FROM view_by_multiple_columns__G;")
rows = db_cursor.fetchall()
for row in rows: 
    print(row)
# Out:
# (0, 2020, 1, 1, 'start', '#23C548')
# (1, 2020, 1, 1, 'start', '#D61FCB')
# (2, 2020, 1, 1, 'start', '#C51283')
# (3, 2020, 1, 1, 'start', '#8242E7')
# (4, 2020, 1, 2, 'stop', '#CDC5AE')
# (5, 2020, 1, 2, 'stop', '#4F63DD')
# (6, 2020, 1, 2, 'start', '#3987C0')
# (7, 2020, 1, 2, 'continue', '#6E0078')
# (8, 2020, 1, 2, 'continue', '#659468')
# (9, 2020, 1, 2, 'continue', '#98E5BF')
# (10, 2020, 1, 2, 'stop', '#D36C69')
# (11, 2020, 1, 2, 'start', '#303094')
# (12, 2020, 1, 3, 'start', '#2B9DBA')
# (13, 2020, 1, 3, 'start', '#03EEB9')
# (14, 2020, 1, 4, 'continue', '#CAF3CC')
# (15, 2020, 1, 5, 'continue', '#6086ED')
# (16, 2020, 1, 5, 'start', '#95E6B0')
# (17, 2020, 1, 5, 'stop', '#CDCA2F')
# (18, 2020, 1, 5, 'continue', '#790D4C')
# (19, 2020, 1, 6, 'continue', '#8520B8')
# (20, 2020, 1, 6, 'continue', '#D94E8F')
# (21, 2020, 1, 6, 'continue', '#5E183D')
# (22, 2020, 1, 7, 'continue', '#2B2E05')
# (23, 2020, 1, 7, 'start', '#52C896')
# (24, 2020, 1, 8, 'start', '#67A822')
# (25, 2020, 1, 9, 'stop', '#BE1598')
# (26, 2020, 1, 9, 'stop', '#B7CC5F')
# (27, 2020, 1, 9, 'continue', '#8A7870')
# (28, 2020, 1, 10, 'start', '#CAD786')
# (29, 2020, 1, 10, 'start', '#25E48E')
# (30, 2020, 1, 10, 'continue', '#544EB9')
# (31, 2020, 1, 10, 'continue', '#C73692')
# (32, 2020, 1, 10, 'start', '#37CAF3')
# (33, 2020, 1, 11, 'stop', '#511061')
# (34, 2020, 1, 11, 'start', '#FEA835')
# (35, 2020, 1, 11, 'continue', '#37C7FE')
# (36, 2020, 1, 11, 'stop', '#C5779E')
# (37, 2020, 1, 12, 'stop', '#C6E8AF')
# (38, 2020, 1, 12, 'continue', '#362100')
# (39, 2020, 1, 12, 'stop', '#FAC96C')
# (40, 2020, 1, 12, 'continue', '#5400C4')
# (41, 2020, 1, 12, 'stop', '#1C842E')
# (42, 2020, 1, 12, 'continue', '#901141')
# (43, 2020, 1, 13, 'stop', '#83D260')
# (44, 2020, 1, 13, 'start', '#F486EC')
# (45, 2020, 1, 14, 'stop', '#A88771')
# (46, 2020, 1, 14, 'stop', '#5BD1BD')
# (47, 2020, 1, 15, 'start', '#6D2828')
# (48, 2020, 1, 15, 'stop', '#53416D')
# (49, 2020, 1, 15, 'stop', '#112FB3')
# (50, 2020, 1, 15, 'start', '#A141E4')
# (51, 2020, 1, 16, 'continue', '#CE0828')
# (52, 2020, 1, 17, 'stop', '#A291C1')
# (53, 2020, 1, 17, 'continue', '#8A48C3')
# (54, 2020, 1, 17, 'start', '#93D76A')
# (55, 2020, 1, 18, 'start', '#ACF34E')
# (56, 2020, 1, 18, 'continue', '#0956BC')
# (57, 2020, 1, 18, 'stop', '#A3DB42')
# (58, 2020, 1, 18, 'continue', '#19AD9A')
# (59, 2020, 1, 19, 'start', '#B8A034')
# (60, 2020, 1, 19, 'continue', '#AAA2E8')
# (61, 2020, 1, 19, 'start', '#FEBC21')
# (62, 2020, 1, 19, 'start', '#41F87A')
# (63, 2020, 1, 19, 'stop', '#BBC9EA')
# (64, 2020, 1, 20, 'stop', '#504874')
# (65, 2020, 1, 20, 'stop', '#35D138')
# (66, 2020, 1, 20, 'continue', '#368222')
# (67, 2020, 1, 20, 'stop', '#65D0BF')
# (68, 2020, 1, 20, 'start', '#976F7D')
# (69, 2020, 1, 21, 'continue', '#EB6F28')
# (70, 2020, 1, 21, 'start', '#D60CF2')
# (71, 2020, 1, 21, 'start', '#CD1BE0')
# (72, 2020, 1, 21, 'stop', '#69039A')
# (73, 2020, 1, 21, 'start', '#9DD9E9')
# (74, 2020, 1, 22, 'start', '#4E4580')
# (75, 2020, 1, 22, 'continue', '#D1BDC9')
# (76, 2020, 1, 22, 'stop', '#0220C8')
# (77, 2020, 1, 22, 'continue', '#E8BFAC')
# (78, 2020, 1, 22, 'continue', '#E3FB4D')
# (79, 2020, 1, 23, 'stop', '#4058B4')
# (80, 2020, 1, 23, 'continue', '#9D89D8')
# (81, 2020, 1, 23, 'continue', '#DAF6FC')
# (82, 2020, 1, 23, 'continue', '#D22464')
# (83, 2020, 1, 24, 'start', '#70384F')
# (84, 2020, 1, 24, 'start', '#3C502D')
# (85, 2020, 1, 24, 'stop', '#16DB13')
# (86, 2020, 1, 24, 'stop', '#D3885F')
# (87, 2020, 1, 25, 'continue', '#162C3E')
# (88, 2020, 1, 25, 'stop', '#9FC3F3')
# (89, 2020, 1, 25, 'start', '#4C658D')
# (90, 2020, 1, 25, 'continue', '#9F6AF3')
# (91, 2020, 1, 25, 'stop', '#0B81E9')
# (92, 2020, 1, 25, 'stop', '#37887D')
# (93, 2020, 1, 25, 'continue', '#4486D1')
# (94, 2020, 1, 25, 'continue', '#4D88F9')
# (95, 2020, 1, 25, 'continue', '#8F6FBF')
# (96, 2020, 1, 25, 'continue', '#7A55E4')
# (97, 2020, 1, 26, 'stop', '#1A46AF')
# (98, 2020, 1, 26, 'continue', '#FA3448')
# (99, 2020, 1, 26, 'start', '#721537')
# (100, 2020, 1, 27, 'start', '#69DA00')
# (101, 2020, 1, 27, 'start', '#97278A')
# (102, 2020, 1, 27, 'continue', '#8C03AB')
# (103, 2020, 1, 27, 'continue', '#43841B')
# (104, 2020, 1, 27, 'stop', '#2239A7')
# (105, 2020, 1, 27, 'start', '#81B024')
# (106, 2020, 1, 27, 'continue', '#CB73A8')
# (107, 2020, 1, 28, 'start', '#0A3B48')
# (108, 2020, 1, 28, 'stop', '#C2FDC9')
# (109, 2020, 1, 28, 'stop', '#794135')
# (110, 2020, 1, 28, 'continue', '#76D808')
# (111, 2020, 1, 29, 'stop', '#88F4C3')
# (112, 2020, 1, 29, 'continue', '#B2B09E')
# (113, 2020, 1, 29, 'stop', '#44246F')
# (114, 2020, 1, 29, 'start', '#AB954C')
# (115, 2020, 1, 29, 'continue', '#EC3489')
# (116, 2020, 1, 29, 'continue', '#004C3E')
# (117, 2020, 1, 30, 'continue', '#0DD8BD')
# (118, 2020, 1, 30, 'stop', '#CE13F1')
# (119, 2020, 1, 30, 'continue', '#0134B8')

# %%
db_cursor.execute("SELECT * FROM view_that_should_be_partitioned_by_random_hash__H;")
rows = db_cursor.fetchall()
for row in rows: 
    print(row)
# Out:
# (0, 'start', '#23C548')
# (1, 'start', '#D61FCB')
# (2, 'start', '#C51283')
# (3, 'start', '#8242E7')
# (4, 'stop', '#CDC5AE')
# (5, 'stop', '#4F63DD')
# (6, 'start', '#3987C0')
# (7, 'continue', '#6E0078')
# (8, 'continue', '#659468')
# (9, 'continue', '#98E5BF')
# (10, 'stop', '#D36C69')
# (11, 'start', '#303094')
# (12, 'start', '#2B9DBA')
# (13, 'start', '#03EEB9')
# (14, 'continue', '#CAF3CC')
# (15, 'continue', '#6086ED')
# (16, 'start', '#95E6B0')
# (17, 'stop', '#CDCA2F')
# (18, 'continue', '#790D4C')
# (19, 'continue', '#8520B8')
# (20, 'continue', '#D94E8F')
# (21, 'continue', '#5E183D')
# (22, 'continue', '#2B2E05')
# (23, 'start', '#52C896')
# (24, 'start', '#67A822')
# (25, 'stop', '#BE1598')
# (26, 'stop', '#B7CC5F')
# (27, 'continue', '#8A7870')
# (28, 'start', '#CAD786')
# (29, 'start', '#25E48E')
# (30, 'continue', '#544EB9')
# (31, 'continue', '#C73692')
# (32, 'start', '#37CAF3')
# (33, 'stop', '#511061')
# (34, 'start', '#FEA835')
# (35, 'continue', '#37C7FE')
# (36, 'stop', '#C5779E')
# (37, 'stop', '#C6E8AF')
# (38, 'continue', '#362100')
# (39, 'stop', '#FAC96C')
# (40, 'continue', '#5400C4')
# (41, 'stop', '#1C842E')
# (42, 'continue', '#901141')
# (43, 'stop', '#83D260')
# (44, 'start', '#F486EC')
# (45, 'stop', '#A88771')
# (46, 'stop', '#5BD1BD')
# (47, 'start', '#6D2828')
# (48, 'stop', '#53416D')
# (49, 'stop', '#112FB3')
# (50, 'start', '#A141E4')
# (51, 'continue', '#CE0828')
# (52, 'stop', '#A291C1')
# (53, 'continue', '#8A48C3')
# (54, 'start', '#93D76A')
# (55, 'start', '#ACF34E')
# (56, 'continue', '#0956BC')
# (57, 'stop', '#A3DB42')
# (58, 'continue', '#19AD9A')
# (59, 'start', '#B8A034')
# (60, 'continue', '#AAA2E8')
# (61, 'start', '#FEBC21')
# (62, 'start', '#41F87A')
# (63, 'stop', '#BBC9EA')
# (64, 'stop', '#504874')
# (65, 'stop', '#35D138')
# (66, 'continue', '#368222')
# (67, 'stop', '#65D0BF')
# (68, 'start', '#976F7D')
# (69, 'continue', '#EB6F28')
# (70, 'start', '#D60CF2')
# (71, 'start', '#CD1BE0')
# (72, 'stop', '#69039A')
# (73, 'start', '#9DD9E9')
# (74, 'start', '#4E4580')
# (75, 'continue', '#D1BDC9')
# (76, 'stop', '#0220C8')
# (77, 'continue', '#E8BFAC')
# (78, 'continue', '#E3FB4D')
# (79, 'stop', '#4058B4')
# (80, 'continue', '#9D89D8')
# (81, 'continue', '#DAF6FC')
# (82, 'continue', '#D22464')
# (83, 'start', '#70384F')
# (84, 'start', '#3C502D')
# (85, 'stop', '#16DB13')
# (86, 'stop', '#D3885F')
# (87, 'continue', '#162C3E')
# (88, 'stop', '#9FC3F3')
# (89, 'start', '#4C658D')
# (90, 'continue', '#9F6AF3')
# (91, 'stop', '#0B81E9')
# (92, 'stop', '#37887D')
# (93, 'continue', '#4486D1')
# (94, 'continue', '#4D88F9')
# (95, 'continue', '#8F6FBF')
# (96, 'continue', '#7A55E4')
# (97, 'stop', '#1A46AF')
# (98, 'continue', '#FA3448')
# (99, 'start', '#721537')
# (100, 'start', '#69DA00')
# (101, 'start', '#97278A')
# (102, 'continue', '#8C03AB')
# (103, 'continue', '#43841B')
# (104, 'stop', '#2239A7')
# (105, 'start', '#81B024')
# (106, 'continue', '#CB73A8')
# (107, 'start', '#0A3B48')
# (108, 'stop', '#C2FDC9')
# (109, 'stop', '#794135')
# (110, 'continue', '#76D808')
# (111, 'stop', '#88F4C3')
# (112, 'continue', '#B2B09E')
# (113, 'stop', '#44246F')
# (114, 'start', '#AB954C')
# (115, 'continue', '#EC3489')
# (116, 'continue', '#004C3E')
# (117, 'continue', '#0DD8BD')
# (118, 'stop', '#CE13F1')
# (119, 'continue', '#0134B8')
