# %% [markdown]
# ## Connect to Data

# %%
import great_expectations as gx

context = gx.get_context()

# %%
validator = context.sources.pandas_default.read_csv(
    "https://raw.githubusercontent.com/great-expectations/gx_tutorials/main/data/yellow_tripdata_sample_2019-01.csv"
)

# %%
context.list_datasources()
# Out:
# [{'type': 'pandas', 'name': 'default_pandas_datasource'}]

# %%
datasource = context.get_datasource("default_pandas_datasource")

# %%
data_asset = datasource.assets[0]

# %%
batch_request = data_asset.build_batch_request()

# %% [markdown]
# ## Inspect Data
#
# (invoked via the Agent via an AgentAction)

# %%
from great_expectations.experimental.column_descriptive_metrics.prototype import (
    CloudStoreBackend,
    ColumnDescriptiveMetricsStore,
    inspect_asset,
)

# %%
# batch_request already has asset
metrics = inspect_asset(data_asset, batch_request)
# Out:
# This method would be invoked via an AgentAction
# Inspecting data asset: #ephemeral_pandas_asset
# NOTE: Here is where we can use things like DomainBuilder and MetricCalculator to calculate metrics
# getting columns
# columns: ['vendor_id', 'pickup_datetime', 'dropoff_datetime', 'passenger_count', 'trip_distance', 'rate_code_id', 'store_and_fwd_flag', 'pickup_location_id', 'dropoff_location_id', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge']
# Getting cardinality metrics
# cardinality_metrics_to_get: {'vendor_id': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "vendor_id",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "4aa90248f235f0a08c7e5a651b0cf990",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "4aa90248f235f0a08c7e5a651b0cf990",
#     []
#   ]
# }], 'pickup_datetime': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "pickup_datetime",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "381897ac8dd00c9e85f25ee96b764463",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "381897ac8dd00c9e85f25ee96b764463",
#     []
#   ]
# }], 'dropoff_datetime': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "dropoff_datetime",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "de0d095bd6a4093a71df7586b932111c",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "de0d095bd6a4093a71df7586b932111c",
#     []
#   ]
# }], 'passenger_count': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "passenger_count",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "f7ad5846430be231ca5d7b4cc3f0557f",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "f7ad5846430be231ca5d7b4cc3f0557f",
#     []
#   ]
# }], 'trip_distance': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "trip_distance",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "c7c9210c9fc25348089e654bb35d65e9",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "c7c9210c9fc25348089e654bb35d65e9",
#     []
#   ]
# }], 'rate_code_id': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "rate_code_id",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "89015f8a6c826a8d4e83ad8198694eb7",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "89015f8a6c826a8d4e83ad8198694eb7",
#     []
#   ]
# }], 'store_and_fwd_flag': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "store_and_fwd_flag",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "72f11e6bd86190d2ac492235cab216e2",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "72f11e6bd86190d2ac492235cab216e2",
#     []
#   ]
# }], 'pickup_location_id': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "pickup_location_id",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "991f5f2853536dce4142c4cb46af6bb5",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "991f5f2853536dce4142c4cb46af6bb5",
#     []
#   ]
# }], 'dropoff_location_id': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "dropoff_location_id",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "ea76569ced3a5ff129981cfa9f615a0a",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "ea76569ced3a5ff129981cfa9f615a0a",
#     []
#   ]
# }], 'payment_type': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "payment_type",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "c3dc8b80d26658fdda696701d9c78140",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "c3dc8b80d26658fdda696701d9c78140",
#     []
#   ]
# }], 'fare_amount': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "fare_amount",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "ad81cc834a5c4a56428a22ddd9a6c63e",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "ad81cc834a5c4a56428a22ddd9a6c63e",
#     []
#   ]
# }], 'extra': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "extra",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "c9f814f46c4ea1a7ae15dc363675ea05",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "c9f814f46c4ea1a7ae15dc363675ea05",
#     []
#   ]
# }], 'mta_tax': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "mta_tax",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "6f6efa02404d31a44709ee9f8a3553ba",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "6f6efa02404d31a44709ee9f8a3553ba",
#     []
#   ]
# }], 'tip_amount': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "tip_amount",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "0f72e5a714368b69f0850dee814b4be7",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "0f72e5a714368b69f0850dee814b4be7",
#     []
#   ]
# }], 'tolls_amount': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "tolls_amount",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "059abb2c1a75328d4db0acd6b94dcf00",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "059abb2c1a75328d4db0acd6b94dcf00",
#     []
#   ]
# }], 'improvement_surcharge': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "improvement_surcharge",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "b013c03656c8ed56ec7241e4e2432f3b",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "b013c03656c8ed56ec7241e4e2432f3b",
#     []
#   ]
# }], 'total_amount': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "total_amount",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "7f0ab4539bb117c169ad102cdc4da6f0",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "7f0ab4539bb117c169ad102cdc4da6f0",
#     []
#   ]
# }], 'congestion_surcharge': [{
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "congestion_surcharge",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "b2876f009913f840ad84b7b30365cec0",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "b2876f009913f840ad84b7b30365cec0",
#     []
#   ]
# }]}
# metric configs to get: [{
#   "metric_name": "table.head",
#   "metric_domain_kwargs": {
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "batch_id=default_pandas_datasource-#ephemeral_pandas_asset",
#   "metric_value_kwargs": {
#     "n_rows": 5
#   },
#   "metric_value_kwargs_id": "n_rows=5",
#   "id": [
#     "table.head",
#     "batch_id=default_pandas_datasource-#ephemeral_pandas_asset",
#     "n_rows=5"
#   ]
# }, {
#   "metric_name": "table.row_count",
#   "metric_domain_kwargs": {
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "batch_id=default_pandas_datasource-#ephemeral_pandas_asset",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "table.row_count",
#     "batch_id=default_pandas_datasource-#ephemeral_pandas_asset",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "vendor_id",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "4aa90248f235f0a08c7e5a651b0cf990",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "4aa90248f235f0a08c7e5a651b0cf990",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "pickup_datetime",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "381897ac8dd00c9e85f25ee96b764463",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "381897ac8dd00c9e85f25ee96b764463",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "dropoff_datetime",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "de0d095bd6a4093a71df7586b932111c",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "de0d095bd6a4093a71df7586b932111c",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "passenger_count",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "f7ad5846430be231ca5d7b4cc3f0557f",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "f7ad5846430be231ca5d7b4cc3f0557f",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "trip_distance",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "c7c9210c9fc25348089e654bb35d65e9",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "c7c9210c9fc25348089e654bb35d65e9",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "rate_code_id",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "89015f8a6c826a8d4e83ad8198694eb7",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "89015f8a6c826a8d4e83ad8198694eb7",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "store_and_fwd_flag",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "72f11e6bd86190d2ac492235cab216e2",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "72f11e6bd86190d2ac492235cab216e2",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "pickup_location_id",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "991f5f2853536dce4142c4cb46af6bb5",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "991f5f2853536dce4142c4cb46af6bb5",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "dropoff_location_id",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "ea76569ced3a5ff129981cfa9f615a0a",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "ea76569ced3a5ff129981cfa9f615a0a",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "payment_type",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "c3dc8b80d26658fdda696701d9c78140",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "c3dc8b80d26658fdda696701d9c78140",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "fare_amount",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "ad81cc834a5c4a56428a22ddd9a6c63e",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "ad81cc834a5c4a56428a22ddd9a6c63e",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "extra",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "c9f814f46c4ea1a7ae15dc363675ea05",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "c9f814f46c4ea1a7ae15dc363675ea05",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "mta_tax",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "6f6efa02404d31a44709ee9f8a3553ba",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "6f6efa02404d31a44709ee9f8a3553ba",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "tip_amount",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "0f72e5a714368b69f0850dee814b4be7",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "0f72e5a714368b69f0850dee814b4be7",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "tolls_amount",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "059abb2c1a75328d4db0acd6b94dcf00",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "059abb2c1a75328d4db0acd6b94dcf00",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "improvement_surcharge",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "b013c03656c8ed56ec7241e4e2432f3b",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "b013c03656c8ed56ec7241e4e2432f3b",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "total_amount",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "7f0ab4539bb117c169ad102cdc4da6f0",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "7f0ab4539bb117c169ad102cdc4da6f0",
#     []
#   ]
# }, {
#   "metric_name": "column.distinct_values.count",
#   "metric_domain_kwargs": {
#     "column": "congestion_surcharge",
#     "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#   },
#   "metric_domain_kwargs_id": "b2876f009913f840ad84b7b30365cec0",
#   "metric_value_kwargs": {},
#   "metric_value_kwargs_id": [],
#   "id": [
#     "column.distinct_values.count",
#     "b2876f009913f840ad84b7b30365cec0",
#     []
#   ]
# }]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 metrics = inspect_asset(data_asset, batch_request)
#
# File ~/src/great_expectations/great_expectations/experimental/column_descriptive_metrics/prototype.py:84, in inspect_asset(asset, batch_request)
#      81 batch = _get_batch(asset, batch_request)
#      83 # TODO: Use DomainBuilder and MetricCalculator to generate.
# ---> 84 metrics = _get_metrics_to_describe_batch(batch)
#      85 return metrics
#
# File ~/src/great_expectations/great_expectations/experimental/column_descriptive_metrics/prototype.py:180, in _get_metrics_to_describe_batch(batch)
#     176 metrics_to_get += _categorical_metrics_to_get(batch)
#     178 print("metric configs to get:", metrics_to_get)
# --> 180 raw_metrics = metric_calculator.get_metrics(
#     181     _convert_list_of_metric_configs_to_get_metrics_format(
#     182         metric_configs=metrics_to_get
#     183     )
#     184 )
#     185 metrics = _convert_metrics_dict_to_metrics_object(raw_metrics=raw_metrics)
#     186 return metrics
#
# File ~/src/great_expectations/great_expectations/validator/metrics_calculator.py:133, in MetricsCalculator.get_metrics(self, metrics)
#     120 def get_metrics(
#     121     self,
#     122     metrics: Dict[str, MetricConfiguration],
#     123 ) -> Dict[str, Any]:
#     124     """
#     125     Args:
#     126         metrics: Dictionary of desired metrics to be resolved; metric_name is key and MetricConfiguration is value.
#    (...)
#     129         Return Dictionary with requested metrics resolved, with metric_name as key and computed metric as value.
#     130     """
#     131     resolved_metrics: Dict[
#     132         Tuple[str, str, str], MetricValue
# --> 133     ] = self.compute_metrics(
#     134         metric_configurations=list(metrics.values()),
#     135         runtime_configuration=None,
#     136         min_graph_edges_pbar_enable=0,
#     137     )
#     138     return {
#     139         metric_configuration.metric_name: resolved_metrics[metric_configuration.id]
#     140         for metric_configuration in metrics.values()
#     141     }
#
# File ~/src/great_expectations/great_expectations/validator/metrics_calculator.py:159, in MetricsCalculator.compute_metrics(self, metric_configurations, runtime_configuration, min_graph_edges_pbar_enable)
#     143 def compute_metrics(
#     144     self,
#     145     metric_configurations: List[MetricConfiguration],
#    (...)
#     148     # Set to low number (e.g., 3) to suppress progress bar for small graphs.
#     149 ) -> Dict[Tuple[str, str, str], MetricValue]:
#     150     """
#     151     Args:
#     152         metric_configurations: List of desired MetricConfiguration objects to be resolved.
#    (...)
#     157         Dictionary with requested metrics resolved, with unique metric ID as key and computed metric as value.
#     158     """
# --> 159     graph: ValidationGraph = self.build_metric_dependency_graph(
#     160         metric_configurations=metric_configurations,
#     161         runtime_configuration=runtime_configuration,
#     162     )
#     163     resolved_metrics: Dict[Tuple[str, str, str], MetricValue]
#     164     aborted_metrics_info: Dict[
#     165         Tuple[str, str, str],
#     166         Dict[str, Union[MetricConfiguration, Set[ExceptionInfo], int]],
#     167     ]
#
# File ~/src/great_expectations/great_expectations/validator/metrics_calculator.py:200, in MetricsCalculator.build_metric_dependency_graph(self, metric_configurations, runtime_configuration)
#     198 metric_configuration: MetricConfiguration
#     199 for metric_configuration in metric_configurations:
# --> 200     graph.build_metric_dependency_graph(
#     201         metric_configuration=metric_configuration,
#     202         runtime_configuration=runtime_configuration,
#     203     )
#     205 return graph
#
# File ~/src/great_expectations/great_expectations/validator/validation_graph.py:127, in ValidationGraph.build_metric_dependency_graph(self, metric_configuration, runtime_configuration)
#     122 metric_impl_klass: MetricProvider
#     123 metric_provider: Callable
#     124 (
#     125     metric_impl_klass,
#     126     metric_provider,
# --> 127 ) = self.set_metric_configuration_default_kwargs_if_absent(
#     128     metric_configuration=metric_configuration
#     129 )
#     131 metric_dependencies = metric_impl_klass.get_evaluation_dependencies(
#     132     metric=metric_configuration,
#     133     execution_engine=self._execution_engine,
#     134     runtime_configuration=runtime_configuration,
#     135 )
#     137 if len(metric_dependencies) == 0:
#
# File ~/src/great_expectations/great_expectations/validator/validation_graph.py:172, in ValidationGraph.set_metric_configuration_default_kwargs_if_absent(self, metric_configuration)
#     169 metric_impl_klass: MetricProvider
#     170 metric_provider: Callable
#     171 metric_impl_klass, metric_provider = get_metric_provider(
# --> 172     metric_name=metric_configuration.metric_name,
#     173     execution_engine=self._execution_engine,
#     174 )
#     175 self._set_default_metric_kwargs_if_absent(
#     176     default_kwarg_values=metric_impl_klass.default_kwarg_values,
#     177     metric_kwargs=metric_configuration.metric_domain_kwargs,
#     178     keys=metric_impl_klass.domain_keys,
#     179 )
#     180 self._set_default_metric_kwargs_if_absent(
#     181     default_kwarg_values=metric_impl_klass.default_kwarg_values,
#     182     metric_kwargs=metric_configuration.metric_value_kwargs,
#     183     keys=metric_impl_klass.value_keys,
#     184 )
#
# AttributeError: 'list' object has no attribute 'metric_name'

# %%
# Another option, invoked via agent:
# asset_inspector = AssetInspector(asset=data_asset)
# metrics = asset_inspector.inspect_batch(batch_request)

# %%
cloud_store_backend = CloudPersistence()

# %%
column_descriptive_metrics_store = ColumnDescriptiveMetricsStore(
    backend=cloud_store_backend
)

# %%
column_descriptive_metrics_store.create(metrics)
